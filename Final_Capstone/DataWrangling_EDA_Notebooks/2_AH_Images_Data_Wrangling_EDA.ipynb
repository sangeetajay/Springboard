# %% [markdown]
# # Final Capstone Project:
# ## Predicting Austin Home Prices from Zillow Images

# %% [markdown]
# ## Data Wrangling/EDA Notebook 2: Images

# %% [markdown]
# Goals: to batch resize images and save the new images in a new folder.
# Purpose of resize: to make images smaller, and all the same size
#
# Then, images will be converted to a numpy array.

# %%
# import packages

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

import PIL
from PIL import Image
from PIL import ImageFile
import os
import glob
import random
from skimage import data
from skimage.color import rgb2gray
from skimage import color
from skimage import io
from skimage.io import imread

# %%
# assign the path of the folder containing the images to a variable 'f'
f = r'/Users/sangeetajayakar/Springboard_Course/AustinHousingFiles/OriginalHomeImages/'

# %%
# get the current working directory
cwd = os.getcwd() 
print(cwd)
# Out:
# /Users/sangeetajayakar/Springboard_Course/Springboard/Final_Capstone

# %%
# change the working directory if it is not the one your images are in:
os.chdir(f)

# %%
# now check that we changed it
cwd = os.getcwd() 
print(cwd)
# Out:
# /Users/sangeetajayakar/Springboard_Course/AustinHousingFiles/OriginalHomeImages

# %%
# read all the file names in a directory using this glob to only get the jpg function
# and assign to the variable 'list_of_pics'
list_of_pics = [p for p in glob.glob(f + '*.jpg')]

#checking the first 3 elements of the list
list_of_pics[:3]
# Out:
# ['/Users/sangeetajayakar/Springboard_Course/AustinHousingFiles/OriginalHomeImages/70342475_47ba545f8d30d79930ead321dcbf11cf-p_f.jpg',
#  '/Users/sangeetajayakar/Springboard_Course/AustinHousingFiles/OriginalHomeImages/29356462_84c5f687b44d9baf99e07c141b2ffe84-p_f.jpg',
#  '/Users/sangeetajayakar/Springboard_Course/AustinHousingFiles/OriginalHomeImages/70345734_ca2eed7fbdf242352ae782837288602f-p_f.jpg']

# %%
### I want to check what the size of the images are (I know they are all
#different sizes 1024X784, 1024X696, 900X680. etc.)

#I don't want to print all 15,000+ sizes, I will check the first 25 pics
for item in list_of_pics[:25]:
    
    image = PIL.Image.open(item)
    width, height = image.size
    print(width, height)
# Out:
# 1024 670
# 1024 682
# 1024 682
# 960 639
# 1024 681
# 1024 683
# 1024 682
# 960 720
# 1024 768
# 1024 768
# 1024 768
# 960 636
# 1024 767
# 1024 508
# 1024 683
# 954 720
# 1024 682
# 960 639
# 960 640
# 960 538
# 1024 768
# 1024 681
# 1024 682
# 1024 681
# 1024 768

# %% [markdown]
# ## Resize the images: make them all smaller, and all the same size:

# %%
# resize all images and output to a new folder:

#the new folder
resized_dir = '/Users/sangeetajayakar/Springboard_Course/AustinHousingFiles/ResizedHomeImages/'

#set the new dimensions
new_width = 300
new_height = 250

# %%
source_folder = '/Users/sangeetajayakar/Springboard_Course/AustinHousingFiles/OriginalHomeImages/'
destination_folder = resized_dir
directory = os.listdir(source_folder)

# %%
# function to resize and export to a new folder- 
# this is commented out so as to not duplicate this action

#from PIL import ImageFile
#ImageFile.LOAD_TRUNCATED_IMAGES = True
#for item in directory:
#    if '.DS_Store' in item:
#        continue
#    img = Image.open(source_folder + item)
#    img.Resize = img.resize((new_width, new_height), Image.ANTIALIAS)
#    img.Resize.save(destination_folder + item, quality = 90)

# %%
# get the current working directory
cwd = os.getcwd() 
print(cwd)
# Out:
# /Users/sangeetajayakar/Springboard_Course/AustinHousingFiles/OriginalHomeImages

# %%
# change the working directory to the newly created resized images
os.chdir(r'/Users/sangeetajayakar/Springboard_Course/AustinHousingFiles/ResizedHomeImages/')

cwd = os.getcwd()
cwd
# Out:
# '/Users/sangeetajayakar/Springboard_Course/AustinHousingFiles/ResizedHomeImages'

# %%
# now we are simply repeating the process of checking the sizes of the resized images

# read all the file names in a directory using this glob to only get the jpg function
# and assign to the variable 'list_of_pics'
list_of_resizedpics = [p for p in glob.glob(cwd + '/*.jpg')]

# %%
# checking the size of the first 25 pics
for resizedpic in list_of_resizedpics[:25]:
    
    image = PIL.Image.open(resizedpic)
    width, height = image.size
    print(width, height)
# Out:
# 300 250
# 300 250
# 300 250
# 300 250
# 300 250
# 300 250
# 300 250
# 300 250
# 300 250
# 300 250
# 300 250
# 300 250
# 300 250
# 300 250
# 300 250
# 300 250
# 300 250
# 300 250
# 300 250
# 300 250
# 300 250
# 300 250
# 300 250
# 300 250
# 300 250

# %%
# now we will try to open a random image
import random
import matplotlib.pyplot as plt

a=random.choice(os.listdir(cwd))
print(a)

file = cwd +'/'+a
im = Image.open(file)
#im.show()

plt.imshow(im)
plt.show()
# Out:
# 250400244_b9ffeebe7e1b2bcbf8fa563f604433df-p_f.jpg

# %%
# now we will try to open a random image
a=random.choice(os.listdir(cwd))
print(a)

file = cwd +'/'+a
im = Image.open(file)
#im.show()

plt.imshow(im)
plt.show()
# Out:
# 29477637_0a593c71444fb82430b4cbca2b229c50-p_f.jpg

# %%
# now we will try to open a random image
a=random.choice(os.listdir(cwd))
print(a)

file = cwd +'/'+a
im = Image.open(file)
#im.show()

print(image.format)
print(image.mode)
print(image.size)

plt.imshow(im)
plt.show()
# Out:
# 64430924_a694d364d57e1c685277242c1bc6a955-p_f.jpg
# JPEG
# RGB
# (300, 250)

# %%
a=random.choice(os.listdir(cwd))
print(a)
a=random.choice(os.listdir(cwd))
print(a)
a=random.choice(os.listdir(cwd))
print(a)
a=random.choice(os.listdir(cwd))
print(a)
# Out:
# 250997722_cb8b4c54894171aebd9ead868a5d52c1-p_f.jpg
# 29513241_7e81c7af0fad564c59be95756e7834db-p_f.jpg
# 122186618_0a2201c21a95612782de51d8923791a4-p_f.jpg
# 58307014_768195c7692c1883e0d0b0d44820ada3-p_f.jpg

# %%
  
# create figure
fig = plt.figure(figsize=(10, 7))
  
# setting values to rows and column variables
rows = 2
columns = 3
  
# reading images

Image1 = Image.open(random.choice(os.listdir(cwd)))
Image2 = Image.open(random.choice(os.listdir(cwd)))
Image3 = Image.open(random.choice(os.listdir(cwd)))
Image4 = Image.open(random.choice(os.listdir(cwd)))
Image5 = Image.open(random.choice(os.listdir(cwd)))
Image6 = Image.open(random.choice(os.listdir(cwd)))

# Adds a subplot at the 1st position
fig.add_subplot(rows, columns, 1)
  
# showing image
plt.imshow(Image1)
plt.axis('off')
plt.title("Image 1")
  
# Adds a subplot at the 2nd position
fig.add_subplot(rows, columns, 2)
  
# showing image
plt.imshow(Image2)
plt.axis('off')
plt.title("Image 2")
  
# Adds a subplot at the 3rd position
fig.add_subplot(rows, columns, 3)
  
# showing image
plt.imshow(Image3)
plt.axis('off')
plt.title("Image 3")
  
# Adds a subplot at the 4th position
fig.add_subplot(rows, columns, 4)
  
# showing image
plt.imshow(Image4)
plt.axis('off')
plt.title("Image 4")

  
# Adds a subplot at the 4th position
fig.add_subplot(rows, columns, 5)
  
# showing image
plt.imshow(Image5)
plt.axis('off')
plt.title("Image 5")

  
# Adds a subplot at the 4th position
fig.add_subplot(rows, columns, 6)
  
# showing image
plt.imshow(Image6)
plt.axis('off')
plt.title("Image 6")
# Out:
# Text(0.5, 1.0, 'Image 6')

# %%
  
# create figure
fig = plt.figure(figsize=(10, 7))
  
# setting values to rows and column variables
rows = 2
columns = 3
  
# reading images

Image1 = Image.open(random.choice(os.listdir(cwd)))
Image2 = Image.open(random.choice(os.listdir(cwd)))
Image3 = Image.open(random.choice(os.listdir(cwd)))
Image4 = Image.open(random.choice(os.listdir(cwd)))
Image5 = Image.open(random.choice(os.listdir(cwd)))
Image6 = Image.open(random.choice(os.listdir(cwd)))

# Adds a subplot at the 1st position
fig.add_subplot(rows, columns, 1)
  
# showing image
plt.imshow(Image1)
plt.axis('off')
plt.title("Image 1")
  
# Adds a subplot at the 2nd position
fig.add_subplot(rows, columns, 2)
  
# showing image
plt.imshow(Image2)
plt.axis('off')
plt.title("Image 2")
  
# Adds a subplot at the 3rd position
fig.add_subplot(rows, columns, 3)
  
# showing image
plt.imshow(Image3)
plt.axis('off')
plt.title("Image 3")
  
# Adds a subplot at the 4th position
fig.add_subplot(rows, columns, 4)
  
# showing image
plt.imshow(Image4)
plt.axis('off')
plt.title("Image 4")

  
# Adds a subplot at the 4th position
fig.add_subplot(rows, columns, 5)
  
# showing image
plt.imshow(Image5)
plt.axis('off')
plt.title("Image 5")

  
# Adds a subplot at the 4th position
fig.add_subplot(rows, columns, 6)
  
# showing image
plt.imshow(Image6)
plt.axis('off')
plt.title("Image 6")
# Out:
# Text(0.5, 1.0, 'Image 6')

# %% [markdown]
# ## Now that the images have been resized, let's convert them to grayscale:

# %% [markdown]
# For our modeling, we will first attempt to evaluate different models using the grayscale images since it will be faster training. Then, when we have an idea of the best model to use, we can try it with the color images.

# %%
resized_dir
# Out:
# '/Users/sangeetajayakar/Springboard_Course/AustinHousingFiles/ResizedHomeImages/'

# %%
gray_dir = '/Users/sangeetajayakar/Springboard_Course/AustinHousingFiles/ResizedGrayImages/'

# %%
source_folder = resized_dir
destination_folder = gray_dir
directory = os.listdir(source_folder)

# %%
# function to convert to gray scale and export to a new folder- 
# this is commented out so as to not duplicate this action

ImageFile.LOAD_TRUNCATED_IMAGES = True


for item in directory:
    if '.DS_Store' in item:
        continue
        image = Image.open(source_folder + item)
# convert the image to grayscale
        gs_image = image.convert(mode='L')
# save in jpeg format
        gs_image.save(destination_folder + item)

# %%
# get the current working directory
cwd = os.getcwd() 
print(cwd)
# Out:
# /Users/sangeetajayakar/Springboard_Course/AustinHousingFiles/ResizedGrayImages

# %%
# change the working directory to the folder with newly created gray images
os.chdir(r'/Users/sangeetajayakar/Springboard_Course/AustinHousingFiles/ResizedGrayImages/')

cwd = os.getcwd()
cwd
# Out:
# '/Users/sangeetajayakar/Springboard_Course/AustinHousingFiles/ResizedGrayImages'

# %%
# now we will try to check one of the images a random image


file = cwd +'/' +'64430924_a694d364d57e1c685277242c1bc6a955-p_f.jpg'
im = Image.open(file)
#im.show()

print(im.format)
print(im.mode)
print(im.size)


plt.imshow(im,cmap='gray')
plt.show()
# Out:
# JPEG
# L
# (300, 250)

# %%
print(gray_dir)
print(resized_dir)
# Out:
# /Users/sangeetajayakar/Springboard_Course/AustinHousingFiles/ResizedGrayImages/
# /Users/sangeetajayakar/Springboard_Course/AustinHousingFiles/ResizedHomeImages/

# %%
  
# create figure
fig = plt.figure(figsize=(10, 7))
  
# setting values to rows and column variables
rows = 1
columns = 2
  
# reading images
filename='64430924_a694d364d57e1c685277242c1bc6a955-p_f.jpg'
file = cwd +'/'+a

Image1 = Image.open(resized_dir+'/'+filename)
Image2 = Image.open(gray_dir+'/'+filename)

# Adds a subplot at the 1st position
fig.add_subplot(rows, columns, 1)
  
# showing image
plt.imshow(Image1)
plt.axis('off')
plt.title("RGB")
  
# Adds a subplot at the 2nd position
fig.add_subplot(rows, columns, 2)
  
# showing image
plt.imshow(Image2, cmap='gray')
plt.axis('off')
plt.title("Grayscale")
# Out:
# Text(0.5, 1.0, 'Grayscale')
