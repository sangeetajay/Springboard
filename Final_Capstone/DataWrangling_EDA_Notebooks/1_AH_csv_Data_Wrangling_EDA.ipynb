# %% [markdown]
# # Final Capstone Project:
# ## Predicting Austin Home Prices from Zillow Images

# %% [markdown]
# ## Data Wrangling/EDA Notebook 1: Accompanying CSV file

# %%
# import packages

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# reading the csv file that accompanied the images indo a dataframe:
file = '/Users/sangeetajayakar/Springboard_Course/AustinHousingFiles/austinHousingData.csv'
df = pd.read_csv(file)
df.head()
# Out:
#          zpid          city          streetAddress  zipcode  \
# 0   111373431  pflugerville   14424 Lake Victor Dr    78660
# 1   120900430  pflugerville     1104 Strickling Dr    78660
# 2  2084491383  pflugerville    1408 Fort Dessau Rd    78660
# 3   120901374  pflugerville     1025 Strickling Dr    78660
# 4    60134862  pflugerville  15005 Donna Jane Loop    78660
#
#                                          description   latitude  longitude  \
# 0  14424 Lake Victor Dr, Pflugerville, TX 78660 i...  30.430632 -97.663078
# 1  Absolutely GORGEOUS 4 Bedroom home with 2 full...  30.432673 -97.661697
# 2  Under construction - estimated completion in A...  30.409748 -97.639771
# 3  Absolutely darling one story home in charming ...  30.432112 -97.661659
# 4  Brimming with appeal & warm livability! Sleek ...  30.437368 -97.656860
#
#    propertyTaxRate  garageSpaces  hasAssociation  ...  numOfMiddleSchools  \
# 0             1.98             2            True  ...                   1
# 1             1.98             2            True  ...                   1
# 2             1.98             0            True  ...                   1
# 3             1.98             2            True  ...                   1
# 4             1.98             0            True  ...                   1
#
#    numOfHighSchools  avgSchoolDistance  avgSchoolRating  avgSchoolSize  \
# 0                 1           1.266667         2.666667           1063
# 1                 1           1.400000         2.666667           1063
# 2                 1           1.200000         3.000000           1108
# 3                 1           1.400000         2.666667           1063
# 4                 1           1.133333         4.000000           1223
#
#   MedianStudentsPerTeacher  numOfBathrooms  numOfBedrooms  numOfStories  \
# 0                       14             3.0              4             2
# 1                       14             2.0              4             1
# 2                       14             2.0              3             1
# 3                       14             2.0              3             1
# 4                       14             3.0              3             2
#
#                                            homeImage
# 0  111373431_ffce26843283d3365c11d81b8e6bdc6f-p_f...
# 1  120900430_8255c127be8dcf0a1a18b7563d987088-p_f...
# 2  2084491383_a2ad649e1a7a098111dcea084a11c855-p_...
# 3  120901374_b469367a619da85b1f5ceb69b675d88e-p_f...
# 4  60134862_b1a48a3df3f111e005bb913873e98ce2-p_f.jpg
#
# [5 rows x 47 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15171 entries, 0 to 15170
# Data columns (total 47 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   zpid                        15171 non-null  int64
#  1   city                        15171 non-null  object
#  2   streetAddress               15171 non-null  object
#  3   zipcode                     15171 non-null  int64
#  4   description                 15171 non-null  object
#  5   latitude                    15171 non-null  float64
#  6   longitude                   15171 non-null  float64
#  7   propertyTaxRate             15171 non-null  float64
#  8   garageSpaces                15171 non-null  int64
#  9   hasAssociation              15171 non-null  bool
#  10  hasCooling                  15171 non-null  bool
#  11  hasGarage                   15171 non-null  bool
#  12  hasHeating                  15171 non-null  bool
#  13  hasSpa                      15171 non-null  bool
#  14  hasView                     15171 non-null  bool
#  15  homeType                    15171 non-null  object
#  16  parkingSpaces               15171 non-null  int64
#  17  yearBuilt                   15171 non-null  int64
#  18  latestPrice                 15171 non-null  float64
#  19  numPriceChanges             15171 non-null  int64
#  20  latest_saledate             15171 non-null  object
#  21  latest_salemonth            15171 non-null  int64
#  22  latest_saleyear             15171 non-null  int64
#  23  latestPriceSource           15171 non-null  object
#  24  numOfPhotos                 15171 non-null  int64
#  25  numOfAccessibilityFeatures  15171 non-null  int64
#  26  numOfAppliances             15171 non-null  int64
#  27  numOfParkingFeatures        15171 non-null  int64
#  28  numOfPatioAndPorchFeatures  15171 non-null  int64
#  29  numOfSecurityFeatures       15171 non-null  int64
#  30  numOfWaterfrontFeatures     15171 non-null  int64
#  31  numOfWindowFeatures         15171 non-null  int64
#  32  numOfCommunityFeatures      15171 non-null  int64
#  33  lotSizeSqFt                 15171 non-null  float64
#  34  livingAreaSqFt              15171 non-null  float64
#  35  numOfPrimarySchools         15171 non-null  int64
#  36  numOfElementarySchools      15171 non-null  int64
#  37  numOfMiddleSchools          15171 non-null  int64
#  38  numOfHighSchools            15171 non-null  int64
#  39  avgSchoolDistance           15171 non-null  float64
#  40  avgSchoolRating             15171 non-null  float64
#  41  avgSchoolSize               15171 non-null  int64
#  42  MedianStudentsPerTeacher    15171 non-null  int64
#  43  numOfBathrooms              15171 non-null  float64
#  44  numOfBedrooms               15171 non-null  int64
#  45  numOfStories                15171 non-null  int64
#  46  homeImage                   15171 non-null  object
# dtypes: bool(6), float64(9), int64(25), object(7)
# memory usage: 4.8+ MB

# %% [markdown]
# Column # 46 'homeImage' is the name of the image file... this will be important as it is how the image files are named.
#
# Column # 18 is 'latestPrice' and this will be the target feature.

# %% [markdown]
# ### Explore the Target Feature: Price

# %%
df['latestPrice'].describe().astype(int)
# Out:
# count       15171
# mean       512767
# std        453185
# min          5500
# 25%        309000
# 50%        405000
# 75%        575000
# max      13500000
# Name: latestPrice, dtype: int64

# %% [markdown]
# ##### Average price is about 500K
# ##### Most expensive home  13.5M
# ##### Cheapest listing is 5500!!

# %%
# exploring the cheapest listings:

df.sort_values(by=['latestPrice'],
axis=0, ascending=True, inplace=False).head(10).T
# Out:
#                                                                         844    \
# zpid                                                                 29361735
# city                                                                   austin
# streetAddress                                                3302 Blue Jay Ln
# zipcode                                                                 78732
# description                 3302 Blue Jay Ln, Austin, TX 78732 is a single...
# latitude                                                              30.3837
# longitude                                                            -97.9135
# propertyTaxRate                                                          1.98
# garageSpaces                                                                4
# hasAssociation                                                          False
# hasCooling                                                               True
# hasGarage                                                                True
# hasHeating                                                               True
# hasSpa                                                                  False
# hasView                                                                 False
# homeType                                                        Single Family
# parkingSpaces                                                               4
# yearBuilt                                                                2000
# latestPrice                                                              5500
# numPriceChanges                                                             9
# latest_saledate                                                    2018-08-14
# latest_salemonth                                                            8
# latest_saleyear                                                          2018
# latestPriceSource                                              Agent Provided
# numOfPhotos                                                                40
# numOfAccessibilityFeatures                                                  0
# numOfAppliances                                                             6
# numOfParkingFeatures                                                        2
# numOfPatioAndPorchFeatures                                                  0
# numOfSecurityFeatures                                                       0
# numOfWaterfrontFeatures                                                     0
# numOfWindowFeatures                                                         0
# numOfCommunityFeatures                                                      0
# lotSizeSqFt                                                              9060
# livingAreaSqFt                                                           4094
# numOfPrimarySchools                                                         1
# numOfElementarySchools                                                      0
# numOfMiddleSchools                                                          1
# numOfHighSchools                                                            1
# avgSchoolDistance                                                     2.93333
# avgSchoolRating                                                       8.33333
# avgSchoolSize                                                            1476
# MedianStudentsPerTeacher                                                   17
# numOfBathrooms                                                              5
# numOfBedrooms                                                               5
# numOfStories                                                                1
# homeImage                   29361735_3cbfc74ca2b80ce53389b3bf3d98d51b-p_f.jpg
#
#                                                                         5796   \
# zpid                                                                 70337317
# city                                                                   austin
# streetAddress                                             1812 Eagles Glen Cv
# zipcode                                                                 78732
# description                 Ideally situated in the prestigious gated Univ...
# latitude                                                               30.355
# longitude                                                            -97.8922
# propertyTaxRate                                                          1.98
# garageSpaces                                                                3
# hasAssociation                                                           True
# hasCooling                                                               True
# hasGarage                                                                True
# hasHeating                                                               True
# hasSpa                                                                   True
# hasView                                                                  True
# homeType                                                        Single Family
# parkingSpaces                                                               3
# yearBuilt                                                                2006
# latestPrice                                                              5600
# numPriceChanges                                                            12
# latest_saledate                                                    2019-07-24
# latest_salemonth                                                            7
# latest_saleyear                                                          2019
# latestPriceSource                                              Agent Provided
# numOfPhotos                                                                84
# numOfAccessibilityFeatures                                                  0
# numOfAppliances                                                             2
# numOfParkingFeatures                                                        2
# numOfPatioAndPorchFeatures                                                  1
# numOfSecurityFeatures                                                       0
# numOfWaterfrontFeatures                                                     0
# numOfWindowFeatures                                                         0
# numOfCommunityFeatures                                                      0
# lotSizeSqFt                                                           14374.8
# livingAreaSqFt                                                           6000
# numOfPrimarySchools                                                         1
# numOfElementarySchools                                                      0
# numOfMiddleSchools                                                          1
# numOfHighSchools                                                            1
# avgSchoolDistance                                                         2.5
# avgSchoolRating                                                       8.33333
# avgSchoolSize                                                            1533
# MedianStudentsPerTeacher                                                   17
# numOfBathrooms                                                              4
# numOfBedrooms                                                               5
# numOfStories                                                                2
# homeImage                   70337317_287bd61606a97c14ca110f64e823fbb6-p_f.jpg
#
#                                                                         785    \
# zpid                                                                 83123966
# city                                                                   austin
# streetAddress                                             7109 Greenshores Dr
# zipcode                                                                 78730
# description                 7109 Greenshores Dr, Austin, TX 78730 is a sin...
# latitude                                                              30.3442
# longitude                                                            -97.8174
# propertyTaxRate                                                          1.98
# garageSpaces                                                                0
# hasAssociation                                                           True
# hasCooling                                                               True
# hasGarage                                                               False
# hasHeating                                                               True
# hasSpa                                                                   True
# hasView                                                                 False
# homeType                                                        Single Family
# parkingSpaces                                                               0
# yearBuilt                                                                2007
# latestPrice                                                              5800
# numPriceChanges                                                            12
# latest_saledate                                                    2019-02-11
# latest_salemonth                                                            2
# latest_saleyear                                                          2019
# latestPriceSource                                              Agent Provided
# numOfPhotos                                                                31
# numOfAccessibilityFeatures                                                  0
# numOfAppliances                                                             5
# numOfParkingFeatures                                                        1
# numOfPatioAndPorchFeatures                                                  0
# numOfSecurityFeatures                                                       0
# numOfWaterfrontFeatures                                                     0
# numOfWindowFeatures                                                         0
# numOfCommunityFeatures                                                      0
# lotSizeSqFt                                                           16117.2
# livingAreaSqFt                                                           4979
# numOfPrimarySchools                                                         1
# numOfElementarySchools                                                      0
# numOfMiddleSchools                                                          1
# numOfHighSchools                                                            1
# avgSchoolDistance                                                         4.7
# avgSchoolRating                                                             7
# avgSchoolSize                                                            1177
# MedianStudentsPerTeacher                                                   16
# numOfBathrooms                                                              6
# numOfBedrooms                                                               5
# numOfStories                                                                2
# homeImage                   83123966_74c1512994aaa4e5f3b0484d4902bece-p_f.jpg
#
#                                                                         9310   \
# zpid                                                                 29381466
# city                                                                   austin
# streetAddress                                                   1907 Holly St
# zipcode                                                                 78702
# description                 Be the first to move in this luxurious home! C...
# latitude                                                               30.253
# longitude                                                            -97.7258
# propertyTaxRate                                                          1.98
# garageSpaces                                                                2
# hasAssociation                                                          False
# hasCooling                                                               True
# hasGarage                                                                True
# hasHeating                                                               True
# hasSpa                                                                  False
# hasView                                                                  True
# homeType                                                        Single Family
# parkingSpaces                                                               2
# yearBuilt                                                                2019
# latestPrice                                                              6000
# numPriceChanges                                                             1
# latest_saledate                                                    2019-08-19
# latest_salemonth                                                            8
# latest_saleyear                                                          2019
# latestPriceSource                                              Agent Provided
# numOfPhotos                                                                25
# numOfAccessibilityFeatures                                                  0
# numOfAppliances                                                             4
# numOfParkingFeatures                                                        2
# numOfPatioAndPorchFeatures                                                  0
# numOfSecurityFeatures                                                       0
# numOfWaterfrontFeatures                                                     0
# numOfWindowFeatures                                                         0
# numOfCommunityFeatures                                                      0
# lotSizeSqFt                                                              6734
# livingAreaSqFt                                                           2330
# numOfPrimarySchools                                                         1
# numOfElementarySchools                                                      0
# numOfMiddleSchools                                                          1
# numOfHighSchools                                                            1
# avgSchoolDistance                                                         1.1
# avgSchoolRating                                                             4
# avgSchoolSize                                                             409
# MedianStudentsPerTeacher                                                   11
# numOfBathrooms                                                              3
# numOfBedrooms                                                               4
# numOfStories                                                                2
# homeImage                   29381466_849d00c9d5446f53b0d876ce57d018b6-p_f.jpg
#
#                                                                         13184  \
# zpid                                                                 29332104
# city                                                                   austin
# streetAddress                                                1500 Hartford Rd
# zipcode                                                                 78703
# description                 1500 Hartford Rd, Austin, TX 78703 is a single...
# latitude                                                               30.285
# longitude                                                            -97.7619
# propertyTaxRate                                                          1.98
# garageSpaces                                                                0
# hasAssociation                                                          False
# hasCooling                                                               True
# hasGarage                                                               False
# hasHeating                                                               True
# hasSpa                                                                  False
# hasView                                                                 False
# homeType                                                        Single Family
# parkingSpaces                                                               0
# yearBuilt                                                                1932
# latestPrice                                                              6300
# numPriceChanges                                                             7
# latest_saledate                                                    2019-02-19
# latest_salemonth                                                            2
# latest_saleyear                                                          2019
# latestPriceSource                                              Agent Provided
# numOfPhotos                                                                12
# numOfAccessibilityFeatures                                                  0
# numOfAppliances                                                             7
# numOfParkingFeatures                                                        3
# numOfPatioAndPorchFeatures                                                  0
# numOfSecurityFeatures                                                       0
# numOfWaterfrontFeatures                                                     0
# numOfWindowFeatures                                                         0
# numOfCommunityFeatures                                                      0
# lotSizeSqFt                                                             10005
# livingAreaSqFt                                                           2693
# numOfPrimarySchools                                                         1
# numOfElementarySchools                                                      0
# numOfMiddleSchools                                                          1
# numOfHighSchools                                                            1
# avgSchoolDistance                                                    0.966667
# avgSchoolRating                                                             7
# avgSchoolSize                                                            1298
# MedianStudentsPerTeacher                                                   16
# numOfBathrooms                                                              4
# numOfBedrooms                                                               6
# numOfStories                                                                2
# homeImage                   29332104_19ceec09c7523a17fedb52c97a9d1bf2-p_f.jpg
#
#                                                                         14335  \
# zpid                                                                 29338824
# city                                                                   austin
# streetAddress                                                   3602 River Rd
# zipcode                                                                 78703
# description                 Beautiful mid century modern home with a conte...
# latitude                                                               30.307
# longitude                                                            -97.7745
# propertyTaxRate                                                          1.98
# garageSpaces                                                                2
# hasAssociation                                                           True
# hasCooling                                                               True
# hasGarage                                                                True
# hasHeating                                                               True
# hasSpa                                                                  False
# hasView                                                                 False
# homeType                                                        Single Family
# parkingSpaces                                                               2
# yearBuilt                                                                1954
# latestPrice                                                              6800
# numPriceChanges                                                             6
# latest_saledate                                                    2020-05-18
# latest_salemonth                                                            5
# latest_saleyear                                                          2020
# latestPriceSource                                              Agent Provided
# numOfPhotos                                                                38
# numOfAccessibilityFeatures                                                  0
# numOfAppliances                                                             3
# numOfParkingFeatures                                                        2
# numOfPatioAndPorchFeatures                                                  1
# numOfSecurityFeatures                                                       1
# numOfWaterfrontFeatures                                                     0
# numOfWindowFeatures                                                         1
# numOfCommunityFeatures                                                      0
# lotSizeSqFt                                                             10149
# livingAreaSqFt                                                           3321
# numOfPrimarySchools                                                         1
# numOfElementarySchools                                                      0
# numOfMiddleSchools                                                          1
# numOfHighSchools                                                            1
# avgSchoolDistance                                                         1.3
# avgSchoolRating                                                             7
# avgSchoolSize                                                            1298
# MedianStudentsPerTeacher                                                   16
# numOfBathrooms                                                              4
# numOfBedrooms                                                               3
# numOfStories                                                                1
# homeImage                   29338824_52bdea518773955cbab4d403e6d691ca-p_f.jpg
#
#                                                                         9272   \
# zpid                                                                 29471989
# city                                                                   austin
# streetAddress                                                     1604 Eva St
# zipcode                                                                 78704
# description                 Rare one-of-a-kind chic home in Bouldin! Priva...
# latitude                                                               30.248
# longitude                                                            -97.7519
# propertyTaxRate                                                          1.98
# garageSpaces                                                                2
# hasAssociation                                                          False
# hasCooling                                                               True
# hasGarage                                                                True
# hasHeating                                                               True
# hasSpa                                                                   True
# hasView                                                                 False
# homeType                                                        Single Family
# parkingSpaces                                                               2
# yearBuilt                                                                1947
# latestPrice                                                              7500
# numPriceChanges                                                             4
# latest_saledate                                                    2020-11-09
# latest_salemonth                                                           11
# latest_saleyear                                                          2020
# latestPriceSource                                              Agent Provided
# numOfPhotos                                                                85
# numOfAccessibilityFeatures                                                  0
# numOfAppliances                                                             2
# numOfParkingFeatures                                                        3
# numOfPatioAndPorchFeatures                                                  3
# numOfSecurityFeatures                                                       1
# numOfWaterfrontFeatures                                                     0
# numOfWindowFeatures                                                         0
# numOfCommunityFeatures                                                      0
# lotSizeSqFt                                                              6882
# livingAreaSqFt                                                           2706
# numOfPrimarySchools                                                         1
# numOfElementarySchools                                                      0
# numOfMiddleSchools                                                          1
# numOfHighSchools                                                            1
# avgSchoolDistance                                                    0.633333
# avgSchoolRating                                                       4.33333
# avgSchoolSize                                                             916
# MedianStudentsPerTeacher                                                   14
# numOfBathrooms                                                              3
# numOfBedrooms                                                               3
# numOfStories                                                                2
# homeImage                   29471989_9bbfa77fb376e1d317c92007edf9ef09-p_f.jpg
#
#                                                                         14580  \
# zpid                                                                 29339192
# city                                                                   austin
# streetAddress                                                2800 Westlake Dr
# zipcode                                                                 78746
# description                 Fabulous, sunny and comfortable in peaceful We...
# latitude                                                              30.3095
# longitude                                                            -97.7816
# propertyTaxRate                                                          1.98
# garageSpaces                                                                2
# hasAssociation                                                          False
# hasCooling                                                               True
# hasGarage                                                                True
# hasHeating                                                               True
# hasSpa                                                                   True
# hasView                                                                  True
# homeType                                                        Single Family
# parkingSpaces                                                               2
# yearBuilt                                                                1993
# latestPrice                                                              7900
# numPriceChanges                                                            18
# latest_saledate                                                    2020-12-11
# latest_salemonth                                                           12
# latest_saleyear                                                          2020
# latestPriceSource                                             Broker Provided
# numOfPhotos                                                               113
# numOfAccessibilityFeatures                                                  0
# numOfAppliances                                                             6
# numOfParkingFeatures                                                        2
# numOfPatioAndPorchFeatures                                                  1
# numOfSecurityFeatures                                                       0
# numOfWaterfrontFeatures                                                     0
# numOfWindowFeatures                                                         0
# numOfCommunityFeatures                                                      0
# lotSizeSqFt                                                             10454
# livingAreaSqFt                                                           4064
# numOfPrimarySchools                                                         0
# numOfElementarySchools                                                      1
# numOfMiddleSchools                                                          1
# numOfHighSchools                                                            0
# avgSchoolDistance                                                        2.65
# avgSchoolRating                                                             9
# avgSchoolSize                                                            1669
# MedianStudentsPerTeacher                                                   15
# numOfBathrooms                                                            4.5
# numOfBedrooms                                                               4
# numOfStories                                                                2
# homeImage                   29339192_cdac2583788ba6e3bb3d40da5285b375-p_f.jpg
#
#                                                                         4823   \
# zpid                                                                 29492341
# city                                                                   austin
# streetAddress                                                   8801 Young Ln
# zipcode                                                                 78737
# description                 Coming soon! This exclusive home is not listed...
# latitude                                                               30.213
# longitude                                                            -97.9212
# propertyTaxRate                                                          1.98
# garageSpaces                                                                3
# hasAssociation                                                           True
# hasCooling                                                               True
# hasGarage                                                                True
# hasHeating                                                               True
# hasSpa                                                                  False
# hasView                                                                  True
# homeType                                                        Single Family
# parkingSpaces                                                               3
# yearBuilt                                                                1999
# latestPrice                                                              8000
# numPriceChanges                                                            10
# latest_saledate                                                    2019-06-27
# latest_salemonth                                                            6
# latest_saleyear                                                          2019
# latestPriceSource                                              Agent Provided
# numOfPhotos                                                                41
# numOfAccessibilityFeatures                                                  0
# numOfAppliances                                                             3
# numOfParkingFeatures                                                        2
# numOfPatioAndPorchFeatures                                                  2
# numOfSecurityFeatures                                                       2
# numOfWaterfrontFeatures                                                     0
# numOfWindowFeatures                                                         2
# numOfCommunityFeatures                                                      0
# lotSizeSqFt                                                           92347.2
# livingAreaSqFt                                                           5526
# numOfPrimarySchools                                                         1
# numOfElementarySchools                                                      0
# numOfMiddleSchools                                                          1
# numOfHighSchools                                                            1
# avgSchoolDistance                                                         2.6
# avgSchoolRating                                                             8
# avgSchoolSize                                                            1655
# MedianStudentsPerTeacher                                                   18
# numOfBathrooms                                                              5
# numOfBedrooms                                                               6
# numOfStories                                                                2
# homeImage                   29492341_abb893089860e58045f09b51842c7db5-p_f.jpg
#
#                                                                         9869
# zpid                                                                 64772328
# city                                                                   austin
# streetAddress                                               4109 E 12th St #2
# zipcode                                                                 78721
# description                 Charming condo in one of Austin's desirable Ea...
# latitude                                                              30.2783
# longitude                                                            -97.6887
# propertyTaxRate                                                          1.98
# garageSpaces                                                                1
# hasAssociation                                                           True
# hasCooling                                                               True
# hasGarage                                                                True
# hasHeating                                                               True
# hasSpa                                                                  False
# hasView                                                                 False
# homeType                                                                Condo
# parkingSpaces                                                               1
# yearBuilt                                                                2007
# latestPrice                                                              8000
# numPriceChanges                                                             4
# latest_saledate                                                    2020-07-13
# latest_salemonth                                                            7
# latest_saleyear                                                          2020
# latestPriceSource                                              Agent Provided
# numOfPhotos                                                                84
# numOfAccessibilityFeatures                                                  0
# numOfAppliances                                                             3
# numOfParkingFeatures                                                        2
# numOfPatioAndPorchFeatures                                                  2
# numOfSecurityFeatures                                                       1
# numOfWaterfrontFeatures                                                     0
# numOfWindowFeatures                                                         0
# numOfCommunityFeatures                                                      0
# lotSizeSqFt                                                              4713
# livingAreaSqFt                                                           1623
# numOfPrimarySchools                                                         1
# numOfElementarySchools                                                      0
# numOfMiddleSchools                                                          1
# numOfHighSchools                                                            1
# avgSchoolDistance                                                     2.03333
# avgSchoolRating                                                       3.33333
# avgSchoolSize                                                             635
# MedianStudentsPerTeacher                                                   13
# numOfBathrooms                                                              2
# numOfBedrooms                                                               3
# numOfStories                                                                2
# homeImage                   64772328_f04c2a0a79803e2f0af99df11d7484bf-p_f.jpg

# %% [markdown]
# Due to being alarmed at a listing for only 5500 USD, I cross checked some of these listings on Zillow. The home at 3302 Blue Jay Ln, Austin, TX 78732 has 5 bedrooms and sold in 2018 for around 2M USD.
#
# I think there must be some errors in the data with these low values. The cheapest listings on Zillow are currently in the 100,000 USD range, with some empty lots as low as 70,000 USD.  I would recommend removing the entries in the dataset that are less than 70,000 USD.

# %%
# get number of entries that are below 70,000 as these could be errors
len(df[df['latestPrice']<70000])
# Out:
# 22

# %%
# exploring the most expensive listings:

df.sort_values(by=['latestPrice'],
axis=0, ascending=False, inplace=False).head(10).T
# Out:
#                                                                         2316   \
# zpid                                                                125904370
# city                                                                   austin
# streetAddress                                                  12400 Cedar St
# zipcode                                                                 78732
# description                 12400 Cedar Street - Villa Del Lago is a uniqu...
# latitude                                                              30.3929
# longitude                                                            -97.8776
# propertyTaxRate                                                          1.98
# garageSpaces                                                                5
# hasAssociation                                                          False
# hasCooling                                                               True
# hasGarage                                                                True
# hasHeating                                                               True
# hasSpa                                                                  False
# hasView                                                                  True
# homeType                                                        Single Family
# parkingSpaces                                                               5
# yearBuilt                                                                2016
# latestPrice                                                          1.35e+07
# numPriceChanges                                                             2
# latest_saledate                                                    2018-11-28
# latest_salemonth                                                           11
# latest_saleyear                                                          2018
# latestPriceSource                                              Agent Provided
# numOfPhotos                                                                13
# numOfAccessibilityFeatures                                                  0
# numOfAppliances                                                             0
# numOfParkingFeatures                                                        2
# numOfPatioAndPorchFeatures                                                  0
# numOfSecurityFeatures                                                       0
# numOfWaterfrontFeatures                                                     0
# numOfWindowFeatures                                                         0
# numOfCommunityFeatures                                                      0
# lotSizeSqFt                                                            710899
# livingAreaSqFt                                                          15394
# numOfPrimarySchools                                                         1
# numOfElementarySchools                                                      0
# numOfMiddleSchools                                                          1
# numOfHighSchools                                                            1
# avgSchoolDistance                                                         2.2
# avgSchoolRating                                                       8.33333
# avgSchoolSize                                                            1476
# MedianStudentsPerTeacher                                                   17
# numOfBathrooms                                                             13
# numOfBedrooms                                                               6
# numOfStories                                                                1
# homeImage                   125904370_a200adec53a31c17278601026747d1ae-p_f...
#
#                                                                         14275  \
# zpid                                                                 80097372
# city                                                                   austin
# streetAddress                                        5909 Lookout Mountain Dr
# zipcode                                                                 78731
# description                 5909 Lookout Mountain Dr, Austin, TX 78731 is ...
# latitude                                                              30.3454
# longitude                                                            -97.7812
# propertyTaxRate                                                          1.98
# garageSpaces                                                                2
# hasAssociation                                                           True
# hasCooling                                                               True
# hasGarage                                                                True
# hasHeating                                                               True
# hasSpa                                                                  False
# hasView                                                                 False
# homeType                                                        Single Family
# parkingSpaces                                                               2
# yearBuilt                                                                2007
# latestPrice                                                           1.3e+07
# numPriceChanges                                                             6
# latest_saledate                                                    2019-03-26
# latest_salemonth                                                            3
# latest_saleyear                                                          2019
# latestPriceSource                                             Broker Provided
# numOfPhotos                                                                 1
# numOfAccessibilityFeatures                                                  0
# numOfAppliances                                                             4
# numOfParkingFeatures                                                        2
# numOfPatioAndPorchFeatures                                                  0
# numOfSecurityFeatures                                                       0
# numOfWaterfrontFeatures                                                     0
# numOfWindowFeatures                                                         0
# numOfCommunityFeatures                                                      0
# lotSizeSqFt                                                             10454
# livingAreaSqFt                                                           4441
# numOfPrimarySchools                                                         1
# numOfElementarySchools                                                      0
# numOfMiddleSchools                                                          1
# numOfHighSchools                                                            1
# avgSchoolDistance                                                     2.53333
# avgSchoolRating                                                             7
# avgSchoolSize                                                            1177
# MedianStudentsPerTeacher                                                   16
# numOfBathrooms                                                              4
# numOfBedrooms                                                               5
# numOfStories                                                                2
# homeImage                   80097372_37e17e1aec16ec7db35015b49907bbfa-p_f.jpg
#
#                                                                         1399   \
# zpid                                                                 29341549
# city                                                                   austin
# streetAddress                                                1101 N Weston Ln
# zipcode                                                                 78733
# description                 This beautiful 10+ acre site has endless possi...
# latitude                                                              30.3234
# longitude                                                            -97.8422
# propertyTaxRate                                                          1.98
# garageSpaces                                                                0
# hasAssociation                                                           True
# hasCooling                                                              False
# hasGarage                                                               False
# hasHeating                                                              False
# hasSpa                                                                  False
# hasView                                                                 False
# homeType                                                          Vacant Land
# parkingSpaces                                                               0
# yearBuilt                                                                1999
# latestPrice                                                         1.272e+07
# numPriceChanges                                                             2
# latest_saledate                                                    2019-07-03
# latest_salemonth                                                            7
# latest_saleyear                                                          2019
# latestPriceSource                                               Public Record
# numOfPhotos                                                                20
# numOfAccessibilityFeatures                                                  0
# numOfAppliances                                                             0
# numOfParkingFeatures                                                        1
# numOfPatioAndPorchFeatures                                                  0
# numOfSecurityFeatures                                                       0
# numOfWaterfrontFeatures                                                     0
# numOfWindowFeatures                                                         0
# numOfCommunityFeatures                                                      0
# lotSizeSqFt                                                            466963
# livingAreaSqFt                                                          11683
# numOfPrimarySchools                                                         0
# numOfElementarySchools                                                      1
# numOfMiddleSchools                                                          3
# numOfHighSchools                                                            0
# avgSchoolDistance                                                     2.96667
# avgSchoolRating                                                       9.33333
# avgSchoolSize                                                            1360
# MedianStudentsPerTeacher                                                   14
# numOfBathrooms                                                              0
# numOfBedrooms                                                               0
# numOfStories                                                                2
# homeImage                   29341549_bfa701f2bc3be479b36dc8f4358a2a6e-p_f.jpg
#
#                                                                         290    \
# zpid                                                                 29344920
# city                                                                   austin
# streetAddress                                             2105 Island Wood Rd
# zipcode                                                                 78733
# description                                                                 -
# latitude                                                              30.3372
# longitude                                                            -97.8467
# propertyTaxRate                                                          1.98
# garageSpaces                                                                3
# hasAssociation                                                           True
# hasCooling                                                               True
# hasGarage                                                                True
# hasHeating                                                               True
# hasSpa                                                                  False
# hasView                                                                  True
# homeType                                                        Single Family
# parkingSpaces                                                               3
# yearBuilt                                                                1985
# latestPrice                                                         8.999e+06
# numPriceChanges                                                             6
# latest_saledate                                                    2020-08-04
# latest_salemonth                                                            8
# latest_saleyear                                                          2020
# latestPriceSource                                              Agent Provided
# numOfPhotos                                                                 1
# numOfAccessibilityFeatures                                                  0
# numOfAppliances                                                             1
# numOfParkingFeatures                                                        2
# numOfPatioAndPorchFeatures                                                  0
# numOfSecurityFeatures                                                       0
# numOfWaterfrontFeatures                                                     0
# numOfWindowFeatures                                                         0
# numOfCommunityFeatures                                                      0
# lotSizeSqFt                                                             87120
# livingAreaSqFt                                                           7745
# numOfPrimarySchools                                                         0
# numOfElementarySchools                                                      1
# numOfMiddleSchools                                                          3
# numOfHighSchools                                                            0
# avgSchoolDistance                                                     3.46667
# avgSchoolRating                                                       9.33333
# avgSchoolSize                                                            1360
# MedianStudentsPerTeacher                                                   14
# numOfBathrooms                                                              8
# numOfBedrooms                                                               7
# numOfStories                                                                2
# homeImage                   29344920_streetviewlocation2105IslandWoodRd2CA...
#
#                                                                         14639  \
# zpid                                                                 29342048
# city                                                                   austin
# streetAddress                                             3904 Waters Edge Dr
# zipcode                                                                 78731
# description                 3904 Waters Edge Dr, Austin, TX 78731 is a sin...
# latitude                                                              30.3221
# longitude                                                            -97.7751
# propertyTaxRate                                                          1.98
# garageSpaces                                                                0
# hasAssociation                                                           True
# hasCooling                                                               True
# hasGarage                                                               False
# hasHeating                                                               True
# hasSpa                                                                  False
# hasView                                                                 False
# homeType                                                        Single Family
# parkingSpaces                                                               0
# yearBuilt                                                                1994
# latestPrice                                                         8.799e+06
# numPriceChanges                                                             5
# latest_saledate                                                    2019-02-09
# latest_salemonth                                                            2
# latest_saleyear                                                          2019
# latestPriceSource                                              Agent Provided
# numOfPhotos                                                                38
# numOfAccessibilityFeatures                                                  0
# numOfAppliances                                                             0
# numOfParkingFeatures                                                        1
# numOfPatioAndPorchFeatures                                                  0
# numOfSecurityFeatures                                                       0
# numOfWaterfrontFeatures                                                     0
# numOfWindowFeatures                                                         0
# numOfCommunityFeatures                                                      0
# lotSizeSqFt                                                             26136
# livingAreaSqFt                                                           6596
# numOfPrimarySchools                                                         1
# numOfElementarySchools                                                      0
# numOfMiddleSchools                                                          1
# numOfHighSchools                                                            1
# avgSchoolDistance                                                     2.13333
# avgSchoolRating                                                             7
# avgSchoolSize                                                            1177
# MedianStudentsPerTeacher                                                   16
# numOfBathrooms                                                              6
# numOfBedrooms                                                               5
# numOfStories                                                                2
# homeImage                   29342048_56039bd96580d98b101d7102d7b3ba14-p_f.jpg
#
#                                                                         1298   \
# zpid                                                                 29344579
# city                                                                   austin
# streetAddress                                                5401 Maryanna Dr
# zipcode                                                                 78746
# description                 Gated private cul-de- sac estate on 5 acres w ...
# latitude                                                              30.3378
# longitude                                                            -97.7903
# propertyTaxRate                                                          1.98
# garageSpaces                                                                0
# hasAssociation                                                           True
# hasCooling                                                               True
# hasGarage                                                               False
# hasHeating                                                               True
# hasSpa                                                                  False
# hasView                                                                 False
# homeType                                                        Single Family
# parkingSpaces                                                               0
# yearBuilt                                                                1982
# latestPrice                                                          8.75e+06
# numPriceChanges                                                             3
# latest_saledate                                                    2018-04-13
# latest_salemonth                                                            4
# latest_saleyear                                                          2018
# latestPriceSource                                              Agent Provided
# numOfPhotos                                                                50
# numOfAccessibilityFeatures                                                  0
# numOfAppliances                                                             2
# numOfParkingFeatures                                                        2
# numOfPatioAndPorchFeatures                                                  0
# numOfSecurityFeatures                                                       0
# numOfWaterfrontFeatures                                                     0
# numOfWindowFeatures                                                         0
# numOfCommunityFeatures                                                      0
# lotSizeSqFt                                                            204296
# livingAreaSqFt                                                           9210
# numOfPrimarySchools                                                         0
# numOfElementarySchools                                                      1
# numOfMiddleSchools                                                          1
# numOfHighSchools                                                            0
# avgSchoolDistance                                                        2.55
# avgSchoolRating                                                             9
# avgSchoolSize                                                            1669
# MedianStudentsPerTeacher                                                   15
# numOfBathrooms                                                              7
# numOfBedrooms                                                               6
# numOfStories                                                                2
# homeImage                   29344579_5e40808cfd108ab09c2f48163f3f1c65-p_f.jpg
#
#                                                                         14376  \
# zpid                                                                 29343242
# city                                                                   austin
# streetAddress                                                 4902 Tortuga Pl
# zipcode                                                                 78731
# description                 Inspired by the 160 ft of Lake Austin waterfro...
# latitude                                                              30.3326
# longitude                                                            -97.7803
# propertyTaxRate                                                          1.98
# garageSpaces                                                                2
# hasAssociation                                                          False
# hasCooling                                                               True
# hasGarage                                                                True
# hasHeating                                                               True
# hasSpa                                                                  False
# hasView                                                                  True
# homeType                                                        Single Family
# parkingSpaces                                                               2
# yearBuilt                                                                1987
# latestPrice                                                          8.75e+06
# numPriceChanges                                                             8
# latest_saledate                                                    2020-04-24
# latest_salemonth                                                            4
# latest_saleyear                                                          2020
# latestPriceSource                                              Agent Provided
# numOfPhotos                                                                44
# numOfAccessibilityFeatures                                                  0
# numOfAppliances                                                             4
# numOfParkingFeatures                                                        2
# numOfPatioAndPorchFeatures                                                  3
# numOfSecurityFeatures                                                       3
# numOfWaterfrontFeatures                                                     0
# numOfWindowFeatures                                                         1
# numOfCommunityFeatures                                                      0
# lotSizeSqFt                                                           79714.8
# livingAreaSqFt                                                           6046
# numOfPrimarySchools                                                         1
# numOfElementarySchools                                                      0
# numOfMiddleSchools                                                          1
# numOfHighSchools                                                            1
# avgSchoolDistance                                                     2.33333
# avgSchoolRating                                                             7
# avgSchoolSize                                                            1177
# MedianStudentsPerTeacher                                                   16
# numOfBathrooms                                                              7
# numOfBedrooms                                                               5
# numOfStories                                                                2
# homeImage                   29343242_96a173d7162f3acc1fe88e8c679b6d1d-p_f.jpg
#
#                                                                         14395  \
# zpid                                                                 29343220
# city                                                                   austin
# streetAddress                                                  4406 Island Cv
# zipcode                                                                 78731
# description                 This beautiful move-in ready estate in the pre...
# latitude                                                              30.3293
# longitude                                                            -97.7783
# propertyTaxRate                                                          1.98
# garageSpaces                                                                0
# hasAssociation                                                           True
# hasCooling                                                               True
# hasGarage                                                               False
# hasHeating                                                               True
# hasSpa                                                                  False
# hasView                                                                  True
# homeType                                                        Single Family
# parkingSpaces                                                               0
# yearBuilt                                                                2001
# latestPrice                                                         6.499e+06
# numPriceChanges                                                             2
# latest_saledate                                                    2018-09-10
# latest_salemonth                                                            9
# latest_saleyear                                                          2018
# latestPriceSource                                              Agent Provided
# numOfPhotos                                                                33
# numOfAccessibilityFeatures                                                  0
# numOfAppliances                                                             5
# numOfParkingFeatures                                                        1
# numOfPatioAndPorchFeatures                                                  0
# numOfSecurityFeatures                                                       0
# numOfWaterfrontFeatures                                                     0
# numOfWindowFeatures                                                         0
# numOfCommunityFeatures                                                      0
# lotSizeSqFt                                                           48787.2
# livingAreaSqFt                                                           7904
# numOfPrimarySchools                                                         1
# numOfElementarySchools                                                      0
# numOfMiddleSchools                                                          1
# numOfHighSchools                                                            1
# avgSchoolDistance                                                     2.23333
# avgSchoolRating                                                             7
# avgSchoolSize                                                            1177
# MedianStudentsPerTeacher                                                   16
# numOfBathrooms                                                              8
# numOfBedrooms                                                               5
# numOfStories                                                                2
# homeImage                   29343220_01fe3e8c5093883f980a0eba86027113-p_f.jpg
#
#                                                                         14627  \
# zpid                                                                 29342058
# city                                                                   austin
# streetAddress                                                3811 Westlake Dr
# zipcode                                                                 78746
# description                 Beautiful contemporary home sitting on 100' of...
# latitude                                                              30.3259
# longitude                                                            -97.7796
# propertyTaxRate                                                          1.98
# garageSpaces                                                                4
# hasAssociation                                                          False
# hasCooling                                                               True
# hasGarage                                                                True
# hasHeating                                                               True
# hasSpa                                                                  False
# hasView                                                                  True
# homeType                                                        Single Family
# parkingSpaces                                                               4
# yearBuilt                                                                2013
# latestPrice                                                          6.25e+06
# numPriceChanges                                                            10
# latest_saledate                                                    2020-02-20
# latest_salemonth                                                            2
# latest_saleyear                                                          2020
# latestPriceSource                                             Broker Provided
# numOfPhotos                                                                53
# numOfAccessibilityFeatures                                                  0
# numOfAppliances                                                             3
# numOfParkingFeatures                                                        3
# numOfPatioAndPorchFeatures                                                  3
# numOfSecurityFeatures                                                       2
# numOfWaterfrontFeatures                                                     0
# numOfWindowFeatures                                                         1
# numOfCommunityFeatures                                                      0
# lotSizeSqFt                                                             37026
# livingAreaSqFt                                                           5775
# numOfPrimarySchools                                                         0
# numOfElementarySchools                                                      1
# numOfMiddleSchools                                                          1
# numOfHighSchools                                                            0
# avgSchoolDistance                                                         2.8
# avgSchoolRating                                                             9
# avgSchoolSize                                                            1669
# MedianStudentsPerTeacher                                                   15
# numOfBathrooms                                                              7
# numOfBedrooms                                                               5
# numOfStories                                                                1
# homeImage                   29342058_7f8838ab682b69c490fbafa6b0435439-p_f.jpg
#
#                                                                         1360
# zpid                                                                 70337612
# city                                                                   austin
# streetAddress                                         14300 Flat Top Ranch Rd
# zipcode                                                                 78732
# description                 Huge Price Improvement. Prized waterfront retr...
# latitude                                                              30.3762
# longitude                                                             -97.913
# propertyTaxRate                                                          1.98
# garageSpaces                                                                0
# hasAssociation                                                           True
# hasCooling                                                               True
# hasGarage                                                               False
# hasHeating                                                               True
# hasSpa                                                                   True
# hasView                                                                  True
# homeType                                                        Single Family
# parkingSpaces                                                               0
# yearBuilt                                                                2006
# latestPrice                                                           6.2e+06
# numPriceChanges                                                             5
# latest_saledate                                                    2019-04-30
# latest_salemonth                                                            4
# latest_saleyear                                                          2019
# latestPriceSource                                              Agent Provided
# numOfPhotos                                                                40
# numOfAccessibilityFeatures                                                  0
# numOfAppliances                                                             3
# numOfParkingFeatures                                                        1
# numOfPatioAndPorchFeatures                                                  0
# numOfSecurityFeatures                                                       0
# numOfWaterfrontFeatures                                                     0
# numOfWindowFeatures                                                         0
# numOfCommunityFeatures                                                      0
# lotSizeSqFt                                                            257004
# livingAreaSqFt                                                          11622
# numOfPrimarySchools                                                         1
# numOfElementarySchools                                                      0
# numOfMiddleSchools                                                          1
# numOfHighSchools                                                            1
# avgSchoolDistance                                                     2.76667
# avgSchoolRating                                                       8.33333
# avgSchoolSize                                                            1476
# MedianStudentsPerTeacher                                                   17
# numOfBathrooms                                                              8
# numOfBedrooms                                                               5
# numOfStories                                                                2
# homeImage                   70337612_b62203248fe4782c119a39a680c188bb-p_f.jpg

# %% [markdown]
# After searching Zillow for their currently listings in Austin and sorting by highest to lowest, the most expensive listing is 12.9M USD.  These data in the dataset were scraped in January 2021, so I think that the listings in the range of 10-13.5M USD are ok. I would not recommend removing any entrees from the higher price end of the dataset.

# %%
# Remove the 22 listings that are less that $70K

df = df[df['latestPrice']>=70000]

# %%
# check that they were removed
df['latestPrice'].describe().astype(int)
# Out:
# count       15149
# mean       513467
# std        453140
# min         70000
# 25%        309000
# 50%        405000
# 75%        575000
# max      13500000
# Name: latestPrice, dtype: int64

# %%
# the min is now 70,000 and the average is now $513,467.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15149 entries, 0 to 15170
# Data columns (total 47 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   zpid                        15149 non-null  int64
#  1   city                        15149 non-null  object
#  2   streetAddress               15149 non-null  object
#  3   zipcode                     15149 non-null  int64
#  4   description                 15149 non-null  object
#  5   latitude                    15149 non-null  float64
#  6   longitude                   15149 non-null  float64
#  7   propertyTaxRate             15149 non-null  float64
#  8   garageSpaces                15149 non-null  int64
#  9   hasAssociation              15149 non-null  bool
#  10  hasCooling                  15149 non-null  bool
#  11  hasGarage                   15149 non-null  bool
#  12  hasHeating                  15149 non-null  bool
#  13  hasSpa                      15149 non-null  bool
#  14  hasView                     15149 non-null  bool
#  15  homeType                    15149 non-null  object
#  16  parkingSpaces               15149 non-null  int64
#  17  yearBuilt                   15149 non-null  int64
#  18  latestPrice                 15149 non-null  float64
#  19  numPriceChanges             15149 non-null  int64
#  20  latest_saledate             15149 non-null  object
#  21  latest_salemonth            15149 non-null  int64
#  22  latest_saleyear             15149 non-null  int64
#  23  latestPriceSource           15149 non-null  object
#  24  numOfPhotos                 15149 non-null  int64
#  25  numOfAccessibilityFeatures  15149 non-null  int64
#  26  numOfAppliances             15149 non-null  int64
#  27  numOfParkingFeatures        15149 non-null  int64
#  28  numOfPatioAndPorchFeatures  15149 non-null  int64
#  29  numOfSecurityFeatures       15149 non-null  int64
#  30  numOfWaterfrontFeatures     15149 non-null  int64
#  31  numOfWindowFeatures         15149 non-null  int64
#  32  numOfCommunityFeatures      15149 non-null  int64
#  33  lotSizeSqFt                 15149 non-null  float64
#  34  livingAreaSqFt              15149 non-null  float64
#  35  numOfPrimarySchools         15149 non-null  int64
#  36  numOfElementarySchools      15149 non-null  int64
#  37  numOfMiddleSchools          15149 non-null  int64
#  38  numOfHighSchools            15149 non-null  int64
#  39  avgSchoolDistance           15149 non-null  float64
#  40  avgSchoolRating             15149 non-null  float64
#  41  avgSchoolSize               15149 non-null  int64
#  42  MedianStudentsPerTeacher    15149 non-null  int64
#  43  numOfBathrooms              15149 non-null  float64
#  44  numOfBedrooms               15149 non-null  int64
#  45  numOfStories                15149 non-null  int64
#  46  homeImage                   15149 non-null  object
# dtypes: bool(6), float64(9), int64(25), object(7)
# memory usage: 4.9+ MB

# %%
# there are now 15149 entries

# %%
# changing the zipcode type to 'string'
df['zipcode'] = df['zipcode'].astype(str)

# %%
# changing the latestPrice type to 'integer'
df['latestPrice'] = df['latestPrice'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15149 entries, 0 to 15170
# Data columns (total 47 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   zpid                        15149 non-null  int64
#  1   city                        15149 non-null  object
#  2   streetAddress               15149 non-null  object
#  3   zipcode                     15149 non-null  object
#  4   description                 15149 non-null  object
#  5   latitude                    15149 non-null  float64
#  6   longitude                   15149 non-null  float64
#  7   propertyTaxRate             15149 non-null  float64
#  8   garageSpaces                15149 non-null  int64
#  9   hasAssociation              15149 non-null  bool
#  10  hasCooling                  15149 non-null  bool
#  11  hasGarage                   15149 non-null  bool
#  12  hasHeating                  15149 non-null  bool
#  13  hasSpa                      15149 non-null  bool
#  14  hasView                     15149 non-null  bool
#  15  homeType                    15149 non-null  object
#  16  parkingSpaces               15149 non-null  int64
#  17  yearBuilt                   15149 non-null  int64
#  18  latestPrice                 15149 non-null  int64
#  19  numPriceChanges             15149 non-null  int64
#  20  latest_saledate             15149 non-null  object
#  21  latest_salemonth            15149 non-null  int64
#  22  latest_saleyear             15149 non-null  int64
#  23  latestPriceSource           15149 non-null  object
#  24  numOfPhotos                 15149 non-null  int64
#  25  numOfAccessibilityFeatures  15149 non-null  int64
#  26  numOfAppliances             15149 non-null  int64
#  27  numOfParkingFeatures        15149 non-null  int64
#  28  numOfPatioAndPorchFeatures  15149 non-null  int64
#  29  numOfSecurityFeatures       15149 non-null  int64
#  30  numOfWaterfrontFeatures     15149 non-null  int64
#  31  numOfWindowFeatures         15149 non-null  int64
#  32  numOfCommunityFeatures      15149 non-null  int64
#  33  lotSizeSqFt                 15149 non-null  float64
#  34  livingAreaSqFt              15149 non-null  float64
#  35  numOfPrimarySchools         15149 non-null  int64
#  36  numOfElementarySchools      15149 non-null  int64
#  37  numOfMiddleSchools          15149 non-null  int64
#  38  numOfHighSchools            15149 non-null  int64
#  39  avgSchoolDistance           15149 non-null  float64
#  40  avgSchoolRating             15149 non-null  float64
#  41  avgSchoolSize               15149 non-null  int64
#  42  MedianStudentsPerTeacher    15149 non-null  int64
#  43  numOfBathrooms              15149 non-null  float64
#  44  numOfBedrooms               15149 non-null  int64
#  45  numOfStories                15149 non-null  int64
#  46  homeImage                   15149 non-null  object
# dtypes: bool(6), float64(8), int64(25), object(8)
# memory usage: 4.9+ MB

# %%
#######################
# Setting fontsizes for graphs

SMALL_SIZE = 16
MEDIUM_SIZE = 20
BIGGER_SIZE = 28

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

#########################

# %%
# Plotting the distribution of the prices
fig, (ax1,ax2) = plt.subplots((2), figsize=(12, 9))

fig.suptitle('Distribution of House Prices', fontsize=40)


ax1.hist(df['latestPrice'], bins=100)
#ax1.ticklabel_format(style='sci')
#ax.set_xscale('log')

#ax1.set_title('')
ax1.set_ylabel('Counts',fontsize=18)
ax1.set_xlabel('Prices in USD', fontsize=18)
ax1.ticklabel_format(style='plain')

ax2.hist(df['latestPrice'], bins=100)

ax2.set_xscale('log')
#ax2.ticklabel_format(style='plain')
#ax2.set_title('Distribution of House Prices')
ax2.set_ylabel('Counts',fontsize=18)
ax2.set_xlabel('Prices in USD on a log scale', fontsize=18)
#ax2.ticklabel_format(style='plain')
plt.show()

# %% [markdown]
# ##### The majority of homes are below 1 million USD.

# %%
print(df['latestPrice'].value_counts())

print('There are ' + str(len(df['latestPrice'].value_counts())) + ' unique values for price.')
# Out:
# 325000    202
# 450000    189
# 375000    182
# 350000    179
# 425000    177
#          ...
# 510250      1
# 583990      1
# 294990      1
# 675900      1
# 499700      1
# Name: latestPrice, Length: 2345, dtype: int64
# There are 2345 unique values for price.

# %% [markdown]
# ### Explore the other features

# %%
df['city'].unique()
df['city'].value_counts()
# Out:
# austin              14998
# del valle              86
# pflugerville           36
# driftwood              12
# manor                   6
# dripping springs        5
# manchaca                3
# west lake hills         2
# road                    1
# Name: city, dtype: int64

# %%
df['homeType'].value_counts()
# Out:
# Single Family            14224
# Condo                      468
# Townhouse                  173
# Multiple Occupancy          96
# Vacant Land                 81
# Apartment                   37
# Residential                 37
# Mobile / Manufactured       17
# MultiFamily                 10
# Other                        6
# Name: homeType, dtype: int64

# %%
 # take away: some of the homes are not listed as in Austin, but most are.
 # most homes are single-family, condo, or townhouse.

# %%
# lets see the 'other' homes:
df[df['homeType']=='Other'].describe().astype(int).T
# Out:
#                             count      mean       std       min       25%  \
# zpid                            6  66620212  45984673  29390994  29474549
# latitude                        6        30         0        30        30
# longitude                       6       -97         0       -97       -97
# propertyTaxRate                 6         2         0         1         1
# garageSpaces                    6         1         1         0         1
# parkingSpaces                   6         1         1         0         1
# yearBuilt                       6      1997        17      1971      1989
# latestPrice                     6    586566    134190    415000    505125
# numPriceChanges                 6         1         0         1         1
# latest_salemonth                6         6         3         2         3
# latest_saleyear                 6      2019         1      2018      2018
# numOfPhotos                     6        21        14         1        12
# numOfAccessibilityFeatures      6         0         0         0         0
# numOfAppliances                 6         3         1         2         3
# numOfParkingFeatures            6         2         0         1         3
# numOfPatioAndPorchFeatures      6         1         1         0         0
# numOfSecurityFeatures           6         0         0         0         0
# numOfWaterfrontFeatures         6         0         0         0         0
# numOfWindowFeatures             6         0         0         0         0
# numOfCommunityFeatures          6         0         0         0         0
# lotSizeSqFt                     6      7280      3196      2347      5945
# livingAreaSqFt                  6      1992       726      1020      1396
# numOfPrimarySchools             6         1         0         1         1
# numOfElementarySchools          6         0         0         0         0
# numOfMiddleSchools              6         1         0         1         1
# numOfHighSchools                6         1         0         1         1
# avgSchoolDistance               6         1         0         0         1
# avgSchoolRating                 6         7         1         4         6
# avgSchoolSize                   6      1287       305       916      1090
# MedianStudentsPerTeacher        6        15         1        14        14
# numOfBathrooms                  6         1         1         0         0
# numOfBedrooms                   6         2         1         0         1
# numOfStories                    6         1         0         1         1
#
#                                  50%        75%        max
# zpid                        47152559  107491412  124838920
# latitude                          30         30         30
# longitude                        -97        -97        -97
# propertyTaxRate                    1          1          2
# garageSpaces                       2          2          3
# parkingSpaces                      2          2          3
# yearBuilt                       1999       2012       2015
# latestPrice                   565000     676250     775900
# numPriceChanges                    2          2          3
# latest_salemonth                   5          9         11
# latest_saleyear                 2020       2020       2020
# numOfPhotos                       25         31         37
# numOfAccessibilityFeatures         0          0          0
# numOfAppliances                    3          4          7
# numOfParkingFeatures               3          3          3
# numOfPatioAndPorchFeatures         0          1          3
# numOfSecurityFeatures              0          1          2
# numOfWaterfrontFeatures            0          0          0
# numOfWindowFeatures                0          0          0
# numOfCommunityFeatures             0          0          0
# lotSizeSqFt                     7514       8722      11761
# livingAreaSqFt                  2324       2511       2622
# numOfPrimarySchools                1          1          1
# numOfElementarySchools             0          0          0
# numOfMiddleSchools                 1          1          1
# numOfHighSchools                   1          1          1
# avgSchoolDistance                  1          1          3
# avgSchoolRating                    7          7          9
# avgSchoolSize                   1224       1539       1670
# MedianStudentsPerTeacher          15         16         18
# numOfBathrooms                     1          2          3
# numOfBedrooms                      2          3          3
# numOfStories                       1          2          2

# %%
# Plotting the number of bedrooms and bathrooms represented in the data

fig, ax = plt.subplots(1, figsize=(6, 4))
plt.hist(df['numOfBedrooms'], bins = 20, alpha=0.5)
plt.hist(df['numOfBathrooms'], bins=20, alpha=0.5)
plt.xlabel('Number of Rooms')
plt.ylabel('Counts')
plt.title('Histogram of Bedrooms and Bathrooms in Zillow Listings')
plt.legend(['Number of Bedrooms', 'Number of Bathrooms'])
#plt.fig_size(3,3)
plt.show()

# %%
# take away: most of the homes have normally distributed data for number of bedrooms and bathrooms. 
# 3 and 4 bedrooms is most common.
# 2 and 3 bathrooms is most common.
# There is a listing with 20 bedrooms and a listing with 27 bathrooms, we will investigate these later.

# %% [markdown]
# ### Feature Correlations

# %%
import seaborn as sns

fig, ax = plt.subplots(1, figsize=(15, 13))
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
# Postive correlation with price: livingAreaSqFt, avgSchoolRating, numofBathrooms

# Negative correlation with price: numOfHighSchools, numOfPrimarySchools

# %%
fig, ax = plt.subplots(2, figsize=(12, 9))
plt.suptitle('Home Prices vs Living Area')
ax[0].scatter(x = df['livingAreaSqFt'], y = df['latestPrice'])
#ax[0].set_xlabel('Living Area in Sq Ft')
#ax[0].set_yscale('linear')
ax[0].ticklabel_format(style='plain')
ax[0].set_ylabel('Price in USD')

ax[1].scatter(x = df['livingAreaSqFt'], y = df['latestPrice'])
ax[1].set_xlabel('Living Area in Sq Ft')
ax[1].set_ylabel("Price on log scale")
ax[1].set_yscale('log')

plt.show()

# %%
# these is a listing with over 100,000 square feet, this seems out of the ordinary, 
# we will investigate this listing

# %%
# exploring the largest home based on living area sq feet

df.sort_values(by=['livingAreaSqFt'],
axis=0, ascending=False, inplace=False).head(10).T
# Out:
#                                                                         705    \
# zpid                                                                 70330356
# city                                                                   austin
# streetAddress                                                   201 Marly Way
# zipcode                                                                 78733
# description                 Level building site with great canyon views an...
# latitude                                                              30.3235
# longitude                                                            -97.8615
# propertyTaxRate                                                          1.98
# garageSpaces                                                                0
# hasAssociation                                                           True
# hasCooling                                                               True
# hasGarage                                                               False
# hasHeating                                                               True
# hasSpa                                                                  False
# hasView                                                                 False
# homeType                                                        Single Family
# parkingSpaces                                                               0
# yearBuilt                                                                2012
# latestPrice                                                            385000
# numPriceChanges                                                             2
# latest_saledate                                                    2018-11-12
# latest_salemonth                                                           11
# latest_saleyear                                                          2018
# latestPriceSource                                              Agent Provided
# numOfPhotos                                                                 1
# numOfAccessibilityFeatures                                                  0
# numOfAppliances                                                             0
# numOfParkingFeatures                                                        1
# numOfPatioAndPorchFeatures                                                  0
# numOfSecurityFeatures                                                       0
# numOfWaterfrontFeatures                                                     0
# numOfWindowFeatures                                                         0
# numOfCommunityFeatures                                                      0
# lotSizeSqFt                                                            109336
# livingAreaSqFt                                                         109292
# numOfPrimarySchools                                                         0
# numOfElementarySchools                                                      1
# numOfMiddleSchools                                                          3
# numOfHighSchools                                                            0
# avgSchoolDistance                                                     3.23333
# avgSchoolRating                                                             8
# avgSchoolSize                                                            1373
# MedianStudentsPerTeacher                                                   14
# numOfBathrooms                                                              0
# numOfBedrooms                                                               5
# numOfStories                                                                2
# homeImage                   70330356_streetviewsize1025x768location30.3235...
#
#                                                                         2557   \
# zpid                                                                 64523076
# city                                                                   austin
# streetAddress                                                  9704 Saugus Ln
# zipcode                                                                 78733
# description                 New Construction, EANES Schools, 4bed 3 bath, ...
# latitude                                                              30.3459
# longitude                                                              -97.86
# propertyTaxRate                                                          1.98
# garageSpaces                                                                0
# hasAssociation                                                           True
# hasCooling                                                               True
# hasGarage                                                               False
# hasHeating                                                               True
# hasSpa                                                                  False
# hasView                                                                 False
# homeType                                                        Single Family
# parkingSpaces                                                               0
# yearBuilt                                                                2018
# latestPrice                                                            829000
# numPriceChanges                                                             1
# latest_saledate                                                    2018-03-08
# latest_salemonth                                                            3
# latest_saleyear                                                          2018
# latestPriceSource                                              Agent Provided
# numOfPhotos                                                                 1
# numOfAccessibilityFeatures                                                  0
# numOfAppliances                                                             1
# numOfParkingFeatures                                                        1
# numOfPatioAndPorchFeatures                                                  0
# numOfSecurityFeatures                                                       0
# numOfWaterfrontFeatures                                                     0
# numOfWindowFeatures                                                         0
# numOfCommunityFeatures                                                      0
# lotSizeSqFt                                                            103237
# livingAreaSqFt                                                          29440
# numOfPrimarySchools                                                         0
# numOfElementarySchools                                                      1
# numOfMiddleSchools                                                          3
# numOfHighSchools                                                            0
# avgSchoolDistance                                                         4.3
# avgSchoolRating                                                             8
# avgSchoolSize                                                            1373
# MedianStudentsPerTeacher                                                   14
# numOfBathrooms                                                              0
# numOfBedrooms                                                               1
# numOfStories                                                                2
# homeImage                   64523076_streetviewlocation9704SaugusLn2CAusti...
#
#                                                                         10588  \
# zpid                                                                 29476730
# city                                                                   austin
# streetAddress                                            3303 Garden Villa Ln
# zipcode                                                                 78704
# description                 3303 Garden Villa Ln, Austin, TX 78704 is a va...
# latitude                                                              30.2349
# longitude                                                            -97.7703
# propertyTaxRate                                                          1.98
# garageSpaces                                                                2
# hasAssociation                                                          False
# hasCooling                                                              False
# hasGarage                                                                True
# hasHeating                                                               True
# hasSpa                                                                  False
# hasView                                                                 False
# homeType                                                          Vacant Land
# parkingSpaces                                                               2
# yearBuilt                                                                2017
# latestPrice                                                            770000
# numPriceChanges                                                             1
# latest_saledate                                                    2018-10-22
# latest_salemonth                                                           10
# latest_saleyear                                                          2018
# latestPriceSource                                              Agent Provided
# numOfPhotos                                                                 1
# numOfAccessibilityFeatures                                                  0
# numOfAppliances                                                             0
# numOfParkingFeatures                                                        4
# numOfPatioAndPorchFeatures                                                  0
# numOfSecurityFeatures                                                       0
# numOfWaterfrontFeatures                                                     0
# numOfWindowFeatures                                                         0
# numOfCommunityFeatures                                                      0
# lotSizeSqFt                                                             17424
# livingAreaSqFt                                                          17536
# numOfPrimarySchools                                                         1
# numOfElementarySchools                                                      0
# numOfMiddleSchools                                                          1
# numOfHighSchools                                                            1
# avgSchoolDistance                                                     1.16667
# avgSchoolRating                                                       3.66667
# avgSchoolSize                                                             861
# MedianStudentsPerTeacher                                                   12
# numOfBathrooms                                                              0
# numOfBedrooms                                                               6
# numOfStories                                                                2
# homeImage                   29476730_streetviewlocation3303GardenVillaLn2C...
#
#                                                                         2316   \
# zpid                                                                125904370
# city                                                                   austin
# streetAddress                                                  12400 Cedar St
# zipcode                                                                 78732
# description                 12400 Cedar Street - Villa Del Lago is a uniqu...
# latitude                                                              30.3929
# longitude                                                            -97.8776
# propertyTaxRate                                                          1.98
# garageSpaces                                                                5
# hasAssociation                                                          False
# hasCooling                                                               True
# hasGarage                                                                True
# hasHeating                                                               True
# hasSpa                                                                  False
# hasView                                                                  True
# homeType                                                        Single Family
# parkingSpaces                                                               5
# yearBuilt                                                                2016
# latestPrice                                                          13500000
# numPriceChanges                                                             2
# latest_saledate                                                    2018-11-28
# latest_salemonth                                                           11
# latest_saleyear                                                          2018
# latestPriceSource                                              Agent Provided
# numOfPhotos                                                                13
# numOfAccessibilityFeatures                                                  0
# numOfAppliances                                                             0
# numOfParkingFeatures                                                        2
# numOfPatioAndPorchFeatures                                                  0
# numOfSecurityFeatures                                                       0
# numOfWaterfrontFeatures                                                     0
# numOfWindowFeatures                                                         0
# numOfCommunityFeatures                                                      0
# lotSizeSqFt                                                            710899
# livingAreaSqFt                                                          15394
# numOfPrimarySchools                                                         1
# numOfElementarySchools                                                      0
# numOfMiddleSchools                                                          1
# numOfHighSchools                                                            1
# avgSchoolDistance                                                         2.2
# avgSchoolRating                                                       8.33333
# avgSchoolSize                                                            1476
# MedianStudentsPerTeacher                                                   17
# numOfBathrooms                                                             13
# numOfBedrooms                                                               6
# numOfStories                                                                1
# homeImage                   125904370_a200adec53a31c17278601026747d1ae-p_f...
#
#                                                                         14257  \
# zpid                                                                 29344391
# city                                                                   austin
# streetAddress                                            5102 Beverly Skyline
# zipcode                                                                 78731
# description                 Large lot near Highland Park Elementary in the...
# latitude                                                              30.3359
# longitude                                                            -97.7654
# propertyTaxRate                                                          1.98
# garageSpaces                                                                0
# hasAssociation                                                          False
# hasCooling                                                               True
# hasGarage                                                               False
# hasHeating                                                               True
# hasSpa                                                                  False
# hasView                                                                 False
# homeType                                                          Vacant Land
# parkingSpaces                                                               0
# yearBuilt                                                                1975
# latestPrice                                                            535000
# numPriceChanges                                                             2
# latest_saledate                                                    2020-04-21
# latest_salemonth                                                            4
# latest_saleyear                                                          2020
# latestPriceSource                                             Broker Provided
# numOfPhotos                                                                11
# numOfAccessibilityFeatures                                                  0
# numOfAppliances                                                             0
# numOfParkingFeatures                                                        2
# numOfPatioAndPorchFeatures                                                  0
# numOfSecurityFeatures                                                       0
# numOfWaterfrontFeatures                                                     0
# numOfWindowFeatures                                                         0
# numOfCommunityFeatures                                                      0
# lotSizeSqFt                                                           13939.2
# livingAreaSqFt                                                          14962
# numOfPrimarySchools                                                         1
# numOfElementarySchools                                                      0
# numOfMiddleSchools                                                          1
# numOfHighSchools                                                            1
# avgSchoolDistance                                                     1.46667
# avgSchoolRating                                                             7
# avgSchoolSize                                                            1177
# MedianStudentsPerTeacher                                                   16
# numOfBathrooms                                                              0
# numOfBedrooms                                                               3
# numOfStories                                                                2
# homeImage                   29344391_d16fa4e175f2edba3425e88d41c5847b-p_f.jpg
#
#                                                                         5328   \
# zpid                                                                 29327226
# city                                                                   austin
# streetAddress                                            3509 Lost Creek Blvd
# zipcode                                                                 78735
# description                 *$6,762,377 is Tax Value - Set in exclusive Ba...
# latitude                                                              30.2722
# longitude                                                             -97.856
# propertyTaxRate                                                          1.98
# garageSpaces                                                                7
# hasAssociation                                                           True
# hasCooling                                                               True
# hasGarage                                                                True
# hasHeating                                                               True
# hasSpa                                                                   True
# hasView                                                                 False
# homeType                                                        Single Family
# parkingSpaces                                                               7
# yearBuilt                                                                2003
# latestPrice                                                           2700000
# numPriceChanges                                                             4
# latest_saledate                                                    2018-05-20
# latest_salemonth                                                            5
# latest_saleyear                                                          2018
# latestPriceSource                                              Agent Provided
# numOfPhotos                                                                39
# numOfAccessibilityFeatures                                                  0
# numOfAppliances                                                             5
# numOfParkingFeatures                                                        3
# numOfPatioAndPorchFeatures                                                  0
# numOfSecurityFeatures                                                       0
# numOfWaterfrontFeatures                                                     0
# numOfWindowFeatures                                                         0
# numOfCommunityFeatures                                                      0
# lotSizeSqFt                                                            138956
# livingAreaSqFt                                                          14091
# numOfPrimarySchools                                                         1
# numOfElementarySchools                                                      0
# numOfMiddleSchools                                                          1
# numOfHighSchools                                                            1
# avgSchoolDistance                                                         4.3
# avgSchoolRating                                                       5.66667
# avgSchoolSize                                                            1332
# MedianStudentsPerTeacher                                                   16
# numOfBathrooms                                                             10
# numOfBedrooms                                                               6
# numOfStories                                                                3
# homeImage                   29327226_811cfb134911b60830174fb4700afc39-p_f.jpg
#
#                                                                         375    \
# zpid                                                                 89551873
# city                                                                   austin
# streetAddress                                         14800 Flat Top Ranch Rd
# zipcode                                                                 78732
# description                 GRACIOUS LUXURY ON LAKE AUSTIN\r\nThis award-w...
# latitude                                                               30.369
# longitude                                                            -97.9127
# propertyTaxRate                                                          1.98
# garageSpaces                                                                6
# hasAssociation                                                           True
# hasCooling                                                               True
# hasGarage                                                                True
# hasHeating                                                               True
# hasSpa                                                                   True
# hasView                                                                  True
# homeType                                                        Single Family
# parkingSpaces                                                               6
# yearBuilt                                                                2014
# latestPrice                                                           4950000
# numPriceChanges                                                             6
# latest_saledate                                                    2018-08-17
# latest_salemonth                                                            8
# latest_saleyear                                                          2018
# latestPriceSource                                              Agent Provided
# numOfPhotos                                                                34
# numOfAccessibilityFeatures                                                  0
# numOfAppliances                                                             3
# numOfParkingFeatures                                                        2
# numOfPatioAndPorchFeatures                                                  0
# numOfSecurityFeatures                                                       0
# numOfWaterfrontFeatures                                                     0
# numOfWindowFeatures                                                         0
# numOfCommunityFeatures                                                      0
# lotSizeSqFt                                                            116741
# livingAreaSqFt                                                          13731
# numOfPrimarySchools                                                         1
# numOfElementarySchools                                                      0
# numOfMiddleSchools                                                          1
# numOfHighSchools                                                            1
# avgSchoolDistance                                                     2.73333
# avgSchoolRating                                                       8.33333
# avgSchoolSize                                                            1476
# MedianStudentsPerTeacher                                                   17
# numOfBathrooms                                                             10
# numOfBedrooms                                                               5
# numOfStories                                                                2
# homeImage                   89551873_acca4b6361693761e8631145233ffd75-p_f.jpg
#
#                                                                         4753   \
# zpid                                                                 29328861
# city                                                                   austin
# streetAddress                                                7702 Sandia Loop
# zipcode                                                                 78735
# description                 Perfectly poised on 4.5+ acres in the highly r...
# latitude                                                              30.2771
# longitude                                                            -97.8602
# propertyTaxRate                                                          1.98
# garageSpaces                                                                5
# hasAssociation                                                           True
# hasCooling                                                               True
# hasGarage                                                                True
# hasHeating                                                               True
# hasSpa                                                                   True
# hasView                                                                 False
# homeType                                                        Single Family
# parkingSpaces                                                               5
# yearBuilt                                                                1999
# latestPrice                                                           2190000
# numPriceChanges                                                            13
# latest_saledate                                                    2019-08-15
# latest_salemonth                                                            8
# latest_saleyear                                                          2019
# latestPriceSource                                              Agent Provided
# numOfPhotos                                                                39
# numOfAccessibilityFeatures                                                  0
# numOfAppliances                                                             3
# numOfParkingFeatures                                                        4
# numOfPatioAndPorchFeatures                                                  2
# numOfSecurityFeatures                                                       0
# numOfWaterfrontFeatures                                                     0
# numOfWindowFeatures                                                         0
# numOfCommunityFeatures                                                      0
# lotSizeSqFt                                                            199940
# livingAreaSqFt                                                          11871
# numOfPrimarySchools                                                         1
# numOfElementarySchools                                                      0
# numOfMiddleSchools                                                          1
# numOfHighSchools                                                            1
# avgSchoolDistance                                                     4.53333
# avgSchoolRating                                                       5.66667
# avgSchoolSize                                                            1332
# MedianStudentsPerTeacher                                                   16
# numOfBathrooms                                                              9
# numOfBedrooms                                                               6
# numOfStories                                                                3
# homeImage                   29328861_40be87f4ed56b4d9bd9e4d90476f33b2-p_f.jpg
#
#                                                                         1399   \
# zpid                                                                 29341549
# city                                                                   austin
# streetAddress                                                1101 N Weston Ln
# zipcode                                                                 78733
# description                 This beautiful 10+ acre site has endless possi...
# latitude                                                              30.3234
# longitude                                                            -97.8422
# propertyTaxRate                                                          1.98
# garageSpaces                                                                0
# hasAssociation                                                           True
# hasCooling                                                              False
# hasGarage                                                               False
# hasHeating                                                              False
# hasSpa                                                                  False
# hasView                                                                 False
# homeType                                                          Vacant Land
# parkingSpaces                                                               0
# yearBuilt                                                                1999
# latestPrice                                                          12720000
# numPriceChanges                                                             2
# latest_saledate                                                    2019-07-03
# latest_salemonth                                                            7
# latest_saleyear                                                          2019
# latestPriceSource                                               Public Record
# numOfPhotos                                                                20
# numOfAccessibilityFeatures                                                  0
# numOfAppliances                                                             0
# numOfParkingFeatures                                                        1
# numOfPatioAndPorchFeatures                                                  0
# numOfSecurityFeatures                                                       0
# numOfWaterfrontFeatures                                                     0
# numOfWindowFeatures                                                         0
# numOfCommunityFeatures                                                      0
# lotSizeSqFt                                                            466963
# livingAreaSqFt                                                          11683
# numOfPrimarySchools                                                         0
# numOfElementarySchools                                                      1
# numOfMiddleSchools                                                          3
# numOfHighSchools                                                            0
# avgSchoolDistance                                                     2.96667
# avgSchoolRating                                                       9.33333
# avgSchoolSize                                                            1360
# MedianStudentsPerTeacher                                                   14
# numOfBathrooms                                                              0
# numOfBedrooms                                                               0
# numOfStories                                                                2
# homeImage                   29341549_bfa701f2bc3be479b36dc8f4358a2a6e-p_f.jpg
#
#                                                                         1360
# zpid                                                                 70337612
# city                                                                   austin
# streetAddress                                         14300 Flat Top Ranch Rd
# zipcode                                                                 78732
# description                 Huge Price Improvement. Prized waterfront retr...
# latitude                                                              30.3762
# longitude                                                             -97.913
# propertyTaxRate                                                          1.98
# garageSpaces                                                                0
# hasAssociation                                                           True
# hasCooling                                                               True
# hasGarage                                                               False
# hasHeating                                                               True
# hasSpa                                                                   True
# hasView                                                                  True
# homeType                                                        Single Family
# parkingSpaces                                                               0
# yearBuilt                                                                2006
# latestPrice                                                           6200000
# numPriceChanges                                                             5
# latest_saledate                                                    2019-04-30
# latest_salemonth                                                            4
# latest_saleyear                                                          2019
# latestPriceSource                                              Agent Provided
# numOfPhotos                                                                40
# numOfAccessibilityFeatures                                                  0
# numOfAppliances                                                             3
# numOfParkingFeatures                                                        1
# numOfPatioAndPorchFeatures                                                  0
# numOfSecurityFeatures                                                       0
# numOfWaterfrontFeatures                                                     0
# numOfWindowFeatures                                                         0
# numOfCommunityFeatures                                                      0
# lotSizeSqFt                                                            257004
# livingAreaSqFt                                                          11622
# numOfPrimarySchools                                                         1
# numOfElementarySchools                                                      0
# numOfMiddleSchools                                                          1
# numOfHighSchools                                                            1
# avgSchoolDistance                                                     2.76667
# avgSchoolRating                                                       8.33333
# avgSchoolSize                                                            1476
# MedianStudentsPerTeacher                                                   17
# numOfBathrooms                                                              8
# numOfBedrooms                                                               5
# numOfStories                                                                2
# homeImage                   70337612_b62203248fe4782c119a39a680c188bb-p_f.jpg

# %%
# it is a 'level building site, no actual home on the site'
# drop the home with unusually large living area
b = df[(df.livingAreaSqFt == 109292)].index
df = df.drop(b)

# %%
# lets plot living area by price again
fig, ax = plt.subplots(2, figsize=(12, 9))
plt.suptitle('Home Prices vs Living Area')
ax[0].scatter(x = df['livingAreaSqFt'], y = df['latestPrice'])
#ax[0].set_xlabel('Living Area in Sq Ft')
ax[0].set_ylabel('Price in USD')

ax[1].scatter(x = df['livingAreaSqFt'], y = df['latestPrice'])
ax[1].set_xlabel('Living Area in Sq Ft')
ax[1].set_ylabel("House Price on log scale")
ax[1].set_yscale('log')

plt.show()

# %%
# price and number of bathrooms:

fig, ax = plt.subplots(2, figsize=(14, 10))
ax[0].scatter(x = df['numOfBedrooms'], y = df['latestPrice'])
ax[0].set_xlabel("bedrooms")
ax[0].set_ylabel("House Price")
ax[0].set_yscale('log')

ax[1].scatter(x = df['numOfBathrooms'], y = df['latestPrice'])
ax[1].set_xlabel("bathrooms")
ax[1].set_ylabel("House Price")
ax[1].set_yscale('log')

plt.show()

# %%
# lets check out the listing with 20 bedrooms:
df.loc[df['numOfBedrooms']==20].T
# Out:
#                                                                          8597
# zpid                                                               2094498207
# city                                                                   austin
# streetAddress                                            4902 Duval Rd R2 #R2
# zipcode                                                                 78727
# description                 Lovely convenient condo, with a private wooded...
# latitude                                                              30.4155
# longitude                                                            -97.7372
# propertyTaxRate                                                          1.98
# garageSpaces                                                                0
# hasAssociation                                                           True
# hasCooling                                                               True
# hasGarage                                                               False
# hasHeating                                                               True
# hasSpa                                                                  False
# hasView                                                                  True
# homeType                                                                Condo
# parkingSpaces                                                               0
# yearBuilt                                                                1985
# latestPrice                                                            174900
# numPriceChanges                                                             2
# latest_saledate                                                    2020-11-13
# latest_salemonth                                                           11
# latest_saleyear                                                          2020
# latestPriceSource                                              Agent Provided
# numOfPhotos                                                                25
# numOfAccessibilityFeatures                                                  0
# numOfAppliances                                                             4
# numOfParkingFeatures                                                        1
# numOfPatioAndPorchFeatures                                                  0
# numOfSecurityFeatures                                                       0
# numOfWaterfrontFeatures                                                     0
# numOfWindowFeatures                                                         0
# numOfCommunityFeatures                                                      0
# lotSizeSqFt                                                              5227
# livingAreaSqFt                                                            916
# numOfPrimarySchools                                                         1
# numOfElementarySchools                                                      0
# numOfMiddleSchools                                                          1
# numOfHighSchools                                                            1
# avgSchoolDistance                                                         2.4
# avgSchoolRating                                                             6
# avgSchoolSize                                                            1474
# MedianStudentsPerTeacher                                                   15
# numOfBathrooms                                                              2
# numOfBedrooms                                                              20
# numOfStories                                                                1
# homeImage                   2094498207_76320ecfd86161cc1d91c46c95c1afcf-p_...

# %%
# this has to be a mistake: A Condo for less than 200K having 20 bedrooms with 2 bathrooms 
# and 900 sq ft does not makes sense. lets drop this entry:

# drop the listing with 20 bedrooms
b = df[(df.numOfBedrooms == 20)].index
df= df.drop(b)

# %%
# lets also check the listing with more than 25 bathrooms
df.loc[df['numOfBathrooms']>20].T
# Out:
#                                                                          2838
# zpid                                                                111972888
# city                                                                   austin
# streetAddress                                              4212 Far West Blvd
# zipcode                                                                 78731
# description                 Well-maintained home in highly desirable North...
# latitude                                                              30.3614
# longitude                                                            -97.7697
# propertyTaxRate                                                          1.98
# garageSpaces                                                                2
# hasAssociation                                                          False
# hasCooling                                                               True
# hasGarage                                                                True
# hasHeating                                                               True
# hasSpa                                                                  False
# hasView                                                                 False
# homeType                                                        Single Family
# parkingSpaces                                                               2
# yearBuilt                                                                1967
# latestPrice                                                            745000
# numPriceChanges                                                             1
# latest_saledate                                                    2020-10-20
# latest_salemonth                                                           10
# latest_saleyear                                                          2020
# latestPriceSource                                              Agent Provided
# numOfPhotos                                                                46
# numOfAccessibilityFeatures                                                  0
# numOfAppliances                                                             4
# numOfParkingFeatures                                                        2
# numOfPatioAndPorchFeatures                                                  0
# numOfSecurityFeatures                                                       0
# numOfWaterfrontFeatures                                                     0
# numOfWindowFeatures                                                         0
# numOfCommunityFeatures                                                      0
# lotSizeSqFt                                                             10236
# livingAreaSqFt                                                           2137
# numOfPrimarySchools                                                         1
# numOfElementarySchools                                                      0
# numOfMiddleSchools                                                          1
# numOfHighSchools                                                            1
# avgSchoolDistance                                                    0.933333
# avgSchoolRating                                                             7
# avgSchoolSize                                                            1483
# MedianStudentsPerTeacher                                                   16
# numOfBathrooms                                                             27
# numOfBedrooms                                                               4
# numOfStories                                                                1
# homeImage                   111972888_a88e572d95e496b1b5d9a591800497c4-p_f...

# %%
# this has to be a mistake: 27 bathrooms with 4 bedrooms and 2000 sq ft does not makes sense. lets drop this entry:
# drop the home with 2 bedrooms
b = df[(df.numOfBathrooms == 27)].index
df = df.drop(b)

# %%
# lets graph the bed/bath rooms again with price:

fig, ax = plt.subplots(2, figsize=(14, 10))

plt.suptitle('Scatter Plot of Home Prices vs Number of Rooms', fontsize=30)
ax[0].scatter(x = df['numOfBedrooms'], y = df['latestPrice'])
ax[0].set_xlabel("bedrooms")
ax[0].set_ylabel("House Price")
ax[0].set_yscale('log')

ax[1].scatter(x = df['numOfBathrooms'], y = df['latestPrice'])
ax[1].set_xlabel("bathrooms")
ax[1].set_ylabel("House Price")
ax[1].set_yscale('log')

plt.show()

# %%
# why are there so many expensive listings with 0 bedrooms and 0 bathrooms?
# let's check these listings out:
df.loc[(df['numOfBedrooms']==0) | (df['numOfBathrooms']==0)].sort_values(['latestPrice'])
# Out:
#             zpid    city             streetAddress zipcode  \
# 964    124904977  austin           12804 River Bnd   78732
# 7267    64784657  austin              11506 Joy St   78748
# 5288    29502899  austin        7902 Persimmon Trl   78745
# 13314   29330022  austin  1405 Hartford Rd APT 202   78703
# 14056   29613814  austin        8404 Alvin High Ln   78729
# ...          ...     ...                       ...     ...
# 14716   29397153  austin           1106 Claire Ave   78703
# 10191   29383466  austin            3201 Holton St   78702
# 1522    63834676  austin   10800 River Terrace Cir   78733
# 13964   29328212  austin          3312 Bee Cave Rd   78746
# 1399    29341549  austin          1101 N Weston Ln   78733
#
#                                              description   latitude  \
# 964    12804 River Bnd, Austin, TX 78732 is a vacant ...  30.329847
# 7267   Fabulous lot in rapidly growing South Austin n...  30.152084
# 5288   Fixer upper!! This home offers a huge kitchen ...  30.187801
# 13314  Old West Austin Efficiency. Close to metro/UT ...  30.284014
# 14056  8404 Alvin High Ln, Austin, TX 78729 is a sing...  30.460995
# ...                                                  ...        ...
# 14716  1106 Claire Ave, Austin, TX 78703 is a single ...  30.294628
# 10191  Welcoming home perfect for your family with a ...  30.257196
# 1522   Remarkable opportunity to build a custom home ...  30.342413
# 13964  Close-in Westlake estate lot on 5.95 park like...  30.275049
# 1399   This beautiful 10+ acre site has endless possi...  30.323383
#
#        longitude  propertyTaxRate  garageSpaces  hasAssociation  ...  \
# 964   -97.926910             1.98             0           False  ...
# 7267  -97.831512             1.98             1           False  ...
# 5288  -97.800835             1.98             0           False  ...
# 13314 -97.762421             1.98             0            True  ...
# 14056 -97.759834             2.21             0            True  ...
# ...          ...              ...           ...             ...  ...
# 14716 -97.749329             1.98             0           False  ...
# 10191 -97.705795             1.98             0           False  ...
# 1522  -97.882538             1.98             1            True  ...
# 13964 -97.801300             1.98             0           False  ...
# 1399  -97.842186             1.98             0            True  ...
#
#        numOfMiddleSchools  numOfHighSchools  avgSchoolDistance  \
# 964                     1                 1           3.833333
# 7267                    1                 1           1.400000
# 5288                    1                 1           1.466667
# 13314                   1                 1           0.600000
# 14056                   1                 1           1.200000
# ...                   ...               ...                ...
# 14716                   1                 1           1.500000
# 10191                   1                 1           1.066667
# 1522                    3                 0           4.600000
# 13964                   1                 0           0.800000
# 1399                    3                 0           2.966667
#
#        avgSchoolRating  avgSchoolSize MedianStudentsPerTeacher  \
# 964           8.333333           1533                       17
# 7267          3.666667           1458                       15
# 5288          3.333333           1409                       14
# 13314         6.000000           1189                       16
# 14056         5.333333           1369                       12
# ...                ...            ...                      ...
# 14716         7.000000           1298                       16
# 10191         3.666667            396                       10
# 1522          8.000000           1373                       14
# 13964         8.500000           1656                       14
# 1399          9.333333           1360                       14
#
#        numOfBathrooms  numOfBedrooms  numOfStories  \
# 964               0.0              3             2
# 7267              0.0              3             1
# 5288              0.0              3             1
# 13314             1.0              0             1
# 14056             0.0              3             1
# ...               ...            ...           ...
# 14716             0.0              4             1
# 10191             0.0              0             1
# 1522              0.0              0             1
# 13964             0.0              0             2
# 1399              0.0              0             2
#
#                                                homeImage
# 964    124904977_1ca138dcc39f9d6183b5512f0df65ad8-p_f...
# 7267   64784657_7e727e180983c94c41045d99b48a52e2-p_f.jpg
# 5288   29502899_ec4154fb5d3e7e06fdde4b3353f7a784-p_f.jpg
# 13314  29330022_325baca18f3fe6664c210987fd58ed8a-p_f.jpg
# 14056  29613814_streetviewlocation8404AlvinHighLn2CAu...
# ...                                                  ...
# 14716  29397153_fda7ae0c8bc3e617bd7ec97fa49c3e08-p_f.jpg
# 10191  29383466_dd8b543940aaa0a11f7a3659ff0c113b-p_f.jpg
# 1522   63834676_32735701edfe4fd626a92e0670ca43c5-p_f.jpg
# 13964  29328212_streetviewlocation3312BeeCaveRd2CAust...
# 1399   29341549_bfa701f2bc3be479b36dc8f4358a2a6e-p_f.jpg
#
# [134 rows x 47 columns]

# %%
# many of these are empty lots, or errors. 
# let's drop all 134 entries with 0 bedrooms or 0 bathrooms listed

b = df[(df['numOfBedrooms']==0) | (df['numOfBathrooms']==0)].index
b
# Out:
# Int64Index([  311,   346,   964,  1023,  1051,  1122,  1399,  1522,  1842,
#              1958,
#             ...
#             14257, 14313, 14357, 14494, 14512, 14622, 14682, 14716, 14789,
#             14972],
#            dtype='int64', length=134)

# %%
df = df.drop(b)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15012 entries, 0 to 15170
# Data columns (total 47 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   zpid                        15012 non-null  int64
#  1   city                        15012 non-null  object
#  2   streetAddress               15012 non-null  object
#  3   zipcode                     15012 non-null  object
#  4   description                 15012 non-null  object
#  5   latitude                    15012 non-null  float64
#  6   longitude                   15012 non-null  float64
#  7   propertyTaxRate             15012 non-null  float64
#  8   garageSpaces                15012 non-null  int64
#  9   hasAssociation              15012 non-null  bool
#  10  hasCooling                  15012 non-null  bool
#  11  hasGarage                   15012 non-null  bool
#  12  hasHeating                  15012 non-null  bool
#  13  hasSpa                      15012 non-null  bool
#  14  hasView                     15012 non-null  bool
#  15  homeType                    15012 non-null  object
#  16  parkingSpaces               15012 non-null  int64
#  17  yearBuilt                   15012 non-null  int64
#  18  latestPrice                 15012 non-null  int64
#  19  numPriceChanges             15012 non-null  int64
#  20  latest_saledate             15012 non-null  object
#  21  latest_salemonth            15012 non-null  int64
#  22  latest_saleyear             15012 non-null  int64
#  23  latestPriceSource           15012 non-null  object
#  24  numOfPhotos                 15012 non-null  int64
#  25  numOfAccessibilityFeatures  15012 non-null  int64
#  26  numOfAppliances             15012 non-null  int64
#  27  numOfParkingFeatures        15012 non-null  int64
#  28  numOfPatioAndPorchFeatures  15012 non-null  int64
#  29  numOfSecurityFeatures       15012 non-null  int64
#  30  numOfWaterfrontFeatures     15012 non-null  int64
#  31  numOfWindowFeatures         15012 non-null  int64
#  32  numOfCommunityFeatures      15012 non-null  int64
#  33  lotSizeSqFt                 15012 non-null  float64
#  34  livingAreaSqFt              15012 non-null  float64
#  35  numOfPrimarySchools         15012 non-null  int64
#  36  numOfElementarySchools      15012 non-null  int64
#  37  numOfMiddleSchools          15012 non-null  int64
#  38  numOfHighSchools            15012 non-null  int64
#  39  avgSchoolDistance           15012 non-null  float64
#  40  avgSchoolRating             15012 non-null  float64
#  41  avgSchoolSize               15012 non-null  int64
#  42  MedianStudentsPerTeacher    15012 non-null  int64
#  43  numOfBathrooms              15012 non-null  float64
#  44  numOfBedrooms               15012 non-null  int64
#  45  numOfStories                15012 non-null  int64
#  46  homeImage                   15012 non-null  object
# dtypes: bool(6), float64(8), int64(25), object(8)
# memory usage: 4.9+ MB

# %%
# lets graph the bed/bath rooms again with price:

fig, ax = plt.subplots(2, figsize=(14, 10))
plt.suptitle('Scatter Plot of Home Prices vs Number of Rooms', fontsize=30)
ax[0].scatter(x = df['numOfBedrooms'], y = df['latestPrice'])
ax[0].set_xlabel("Number of Bedrooms")
ax[0].set_xlim(0,12)
ax[0].set_ylabel("House Price in USD")
ax[0].set_yscale('log')

ax[1].scatter(x = df['numOfBathrooms'], y = df['latestPrice'])
ax[1].set_xlabel("Number of Bathrooms")
ax[1].set_xlim(0,12)

ax[1].set_ylabel("House Price in USD")
ax[1].set_yscale('log')

plt.show()

# %%
# bedrooms plot looks ok.
# bathroom plot has a lot of points in between 1 and 3 that seem odd. let's check these out:
# lets see what the unique values are..
df.numOfBathrooms.value_counts().sort_index()
# Out:
# 1.00      922
# 1.50       13
# 1.70        1
# 1.75        3
# 2.00     6090
# 2.50      125
# 2.75        2
# 3.00     5277
# 3.50       44
# 4.00     1881
# 4.50        4
# 5.00      405
# 5.50        2
# 6.00      156
# 6.50        1
# 7.00       61
# 8.00       17
# 9.00        2
# 10.00       5
# 13.00       1
# Name: numOfBathrooms, dtype: int64

# %%
# everything seems ok, except for 1.7 and 1.75 bathrooms. we will change these to 1.5
# 2.75 bathrooms seems off, we will change these to 2.5 bathrooms. 
# all other values for bathrooms seem reasonable (either a whole number or ending in .5 (half bath))
df.loc[(df['numOfBathrooms']==1.70) | (df['numOfBathrooms']==1.75), 'numOfBathrooms'] = 1.5

df.loc[df['numOfBathrooms']==2.75, 'numOfBathrooms'] = 2.5

df.numOfBathrooms.value_counts().sort_index()
# Out:
# 1.0      922
# 1.5       17
# 2.0     6090
# 2.5      127
# 3.0     5277
# 3.5       44
# 4.0     1881
# 4.5        4
# 5.0      405
# 5.5        2
# 6.0      156
# 6.5        1
# 7.0       61
# 8.0       17
# 9.0        2
# 10.0       5
# 13.0       1
# Name: numOfBathrooms, dtype: int64

# %%
# checking out the columns we are interested in graphing 
df[['numOfBedrooms', 'numOfBathrooms', 'latestPrice']].head()
# Out:
#    numOfBedrooms  numOfBathrooms  latestPrice
# 0              4             3.0       305000
# 1              4             2.0       295000
# 2              3             2.0       256125
# 3              3             2.0       240000
# 4              3             3.0       239900

# %%
# lets now plot this as a BOXPLOT instead  
df.boxplot(column=['latestPrice'], by=['numOfBedrooms'], figsize=(20,8))
plt.ticklabel_format(style='plain', axis='y')
plt.yscale('log')

plt.ylabel('Price in USD on log scale', fontsize=28)
#plt.title('Home Prices Grouped by Number of Rooms')
plt.title('Home Prices Grouped by Number of Bedrooms', fontsize=36)

plt.suptitle('')

plt.show()

# %%
df.boxplot(column=['latestPrice'], by=['numOfBathrooms'], figsize=(20,8))
plt.ticklabel_format(style='plain', axis='y')
plt.yscale('log')

plt.ylabel('Price in USD on log scale', fontsize=28)
plt.title('Home Prices Grouped by Number of Bathrooms', fontsize=36)

plt.suptitle('')
plt.show()

# %%
# Plotting the number of bedrooms and bathrooms represented in the data

fig, ax = plt.subplots(1, figsize=(6, 4))
plt.suptitle('Distribution of Rooms in Zillow Listings', fontsize=30)
plt.hist(df['numOfBedrooms'], bins = 20, alpha=0.5)
plt.hist(df['numOfBathrooms'], bins=20, alpha=0.5)
plt.xlabel('Number of Rooms', fontsize=20)
plt.ylabel('Counts', fontsize=20)
#plt.title('Distribution of Rooms in Zillow Listings', fontsize=30)
plt.legend(['Number of Bedrooms', 'Number of Bathrooms'])
plt.show()

# %%
# lets plot living area by price again
fig, ax = plt.subplots(1, figsize=(6, 4))
plt.scatter(df['livingAreaSqFt'], df['latestPrice'], alpha=.2)
plt.xlabel('Living Area in Sq Ft', fontsize=20)
plt.ylabel("Home Price in USD (log scale)", fontsize=20)
plt.yscale('log')
plt.title('Home Prices by Living Area', fontsize=24)
#plt.plot.scatter(x = df['livingAreaSqFt'], y = df['latestPrice'])
#ax.set_xlabel('Living Area in Sq Ft')
#ax.set_ylabel("House Price on log scale")
#ax.set_yscale('log')

#plt.show()
# Out:
# Text(0.5, 1.0, 'Home Prices by Living Area')

# %%
fig, ax = plt.subplots(1, figsize=(6,4))
df['livingAreaSqFt'].hist(bins=60)
plt.xlabel('Living Area in Square Feet', fontsize=20)
plt.ylabel('Counts', fontsize=20)
plt.title('Distribution of Living Area in Home Listings', fontsize=24)

plt.show()

# %%
# Plotting the above 2 living area graphs next to eachother
fig, (ax1,ax2) = plt.subplots(1,2)
plt.rcParams["figure.figsize"] = (16,8)
#fig.suptitle('Living Area and Home Prices', fontsize=40)
#fig.suptitle('Living Area and Price')

ax1.hist(df['livingAreaSqFt'], bins=100)
ax1.set_title('Distribution of Living Area', fontsize=30)
#ax.set_xscale('log')

ax1.set_ylabel('Counts',fontsize=18)
ax1.set_xlabel('Home Prices in USD', fontsize=18)
ax1.ticklabel_format(style='plain')

ax2.scatter(df['livingAreaSqFt'], df['latestPrice'], alpha=0.2)
ax2.set_xscale('log')
#ax2.ticklabel_format(style='plain')
ax2.set_title('Home Prices by Living Area', fontsize=30)
ax2.set_ylabel('Home Prices in USD (log scale)',fontsize=18)
ax2.set_yscale('log')
ax2.set_xlabel('Living Area in Sq Ft (log scale)', fontsize=18)

plt.show()

# %%
# lets plot living area by price again
fig, ax = plt.subplots(1, figsize=(12, 8))
plt.scatter(df['livingAreaSqFt'], df['latestPrice'], alpha=.2)
plt.xlabel('Living Area in Sq Ft', fontsize=20)
plt.ylabel("Home Price in USD (log scale)", fontsize=28)
plt.yscale('log')
plt.title('Home Prices by Living Area', fontsize=36)
#plt.plot.scatter(x = df['livingAreaSqFt'], y = df['latestPrice'])
#ax.set_xlabel('Living Area in Sq Ft')
#ax.set_ylabel("House Price on log scale")
#ax.set_yscale('log')

#plt.show()
# Out:
# Text(0.5, 1.0, 'Home Prices by Living Area')

# %%
# Plotting the distribution of the prices
fig, (ax1,ax2) = plt.subplots(2,1)
plt.rcParams["figure.figsize"] = (20,12)
fig.suptitle('Distribution of House Prices', fontsize=40)


ax1.hist(df['latestPrice'], bins=100)
#ax1.ticklabel_format(style='sci')
#ax.set_xscale('log')

#ax1.set_title('')
ax1.set_ylabel('Counts')
ax1.set_xlabel('Prices in USD')
ax1.ticklabel_format(style='plain')

ax2.hist(df['latestPrice'], bins=100)

ax2.set_xscale('log')
#ax2.ticklabel_format(style='plain')
#ax2.set_title('Distribution of House Prices')
ax2.set_ylabel('Counts')
ax2.set_xlabel('Prices in USD on a log scale')

plt.show()

# %%
df.describe().astype(int).T
# Out:
#                             count       mean        std       min       25%  \
# zpid                        15012  104342568  317467460  28584946  29411379
# latitude                    15012         30          0        30        30
# longitude                   15012        -97          0       -98       -97
# propertyTaxRate             15012          1          0         1         1
# garageSpaces                15012          1          1         0         0
# parkingSpaces               15012          1          1         0         0
# yearBuilt                   15012       1988         21      1905      1975
# latestPrice                 15012     512613     442040     70000    309033
# numPriceChanges             15012          3          2         1         1
# latest_salemonth            15012          6          3         1         4
# latest_saleyear             15012       2019          0      2018      2018
# numOfPhotos                 15012         30         21         1        20
# numOfAccessibilityFeatures  15012          0          0         0         0
# numOfAppliances             15012          3          1         0         2
# numOfParkingFeatures        15012          1          0         0         1
# numOfPatioAndPorchFeatures  15012          0          0         0         0
# numOfSecurityFeatures       15012          0          0         0         0
# numOfWaterfrontFeatures     15012          0          0         0         0
# numOfWindowFeatures         15012          0          0         0         0
# numOfCommunityFeatures      15012          0          0         0         0
# lotSizeSqFt                 15012     120089   12317434       100      6534
# livingAreaSqFt              15012       2196       1023       300      1486
# numOfPrimarySchools         15012          0          0         0         1
# numOfElementarySchools      15012          0          0         0         0
# numOfMiddleSchools          15012          1          0         0         1
# numOfHighSchools            15012          0          0         0         1
# avgSchoolDistance           15012          1          1         0         1
# avgSchoolRating             15012          5          1         2         4
# avgSchoolSize               15012       1238        325       396       966
# MedianStudentsPerTeacher    15012         14          1        10        14
# numOfBathrooms              15012          2          1         1         2
# numOfBedrooms               15012          3          0         1         3
# numOfStories                15012          1          0         1         1
#
#                                  50%       75%         max
# zpid                        29494883  70338534  2146313225
# latitude                          30        30          30
# longitude                        -97       -97         -97
# propertyTaxRate                    1         1           2
# garageSpaces                       1         2          22
# parkingSpaces                      1         2          22
# yearBuilt                       1993      2006        2020
# latestPrice                   405000    575000    13500000
# numPriceChanges                    2         4          23
# latest_salemonth                   7         9          12
# latest_saleyear                 2019      2020        2021
# numOfPhotos                       29        39         179
# numOfAccessibilityFeatures         0         0           8
# numOfAppliances                    3         4          12
# numOfParkingFeatures               2         2           6
# numOfPatioAndPorchFeatures         0         1           8
# numOfSecurityFeatures              0         1           6
# numOfWaterfrontFeatures            0         0           2
# numOfWindowFeatures                0         0           4
# numOfCommunityFeatures             0         0           8
# lotSizeSqFt                     8276     10890  1508482800
# livingAreaSqFt                  1976      2686       15394
# numOfPrimarySchools                1         1           2
# numOfElementarySchools             0         0           2
# numOfMiddleSchools                 1         1           3
# numOfHighSchools                   1         1           2
# avgSchoolDistance                  1         2           9
# avgSchoolRating                    5         7           9
# avgSchoolSize                   1287      1496        1913
# MedianStudentsPerTeacher          15        16          19
# numOfBathrooms                     3         3          13
# numOfBedrooms                      3         4          10
# numOfStories                       1         2           4

# %%
#boxplot of price
from matplotlib import ticker
df.latestPrice.plot(kind='box', figsize=(8,8))
plt.ticklabel_format(style='plain', axis='y')
ax.get_yaxis().set_major_formatter(ticker.FuncFormatter(lambda x, p: format(int(x)/1000000, ',')))
plt.ylabel('Price in USD')
plt.title('Boxplot of all Home Prices')
plt.show()

# %%
# exploring zipcodes because this may affect price:

# %%
print(len(df['zipcode'].unique()))  # number of unique zipcodes = 48
df['zipcode'].value_counts()
# Out:
# 48
# 78748    1137
# 78745    1025
# 78749     772
# 78704     693
# 78737     611
# 78739     604
# 78732     591
# 78759     559
# 78723     554
# 78757     519
# 78717     515
# 78731     490
# 78744     469
# 78753     439
# 78727     414
# 78754     393
# 78758     392
# 78702     383
# 78747     379
# 78750     321
# 78729     317
# 78735     308
# 78703     295
# 78721     244
# 78730     243
# 78728     224
# 78724     221
# 78741     217
# 78733     203
# 78746     191
# 78726     178
# 78751     172
# 78736     162
# 78725     161
# 78752     151
# 78756     137
# 78722      96
# 78617      85
# 78705      64
# 78660      36
# 78619      12
# 78734       9
# 78701       8
# 78719       5
# 78652       4
# 78653       4
# 78742       4
# 78738       1
# Name: zipcode, dtype: int64

# %%
# exploring zip code and price

# %%
df.boxplot(column=['latestPrice'], by=['zipcode'], figsize=(20,8), rot=90)

plt.ticklabel_format(style='plain', axis='y')

#plt.xticklabels(rotation=90)
plt.yscale('log')
plt.ylabel('Price in USD on log scale', fontsize=28)
plt.title('Home Prices Grouped by Zip Code', fontsize=36)

plt.suptitle('')
plt.show()

# %%
# conclusion: zipcode may be important in predicting the price of a home

# %%
# exploring school rating
df['avgSchoolRating'].describe()
# Out:
# count    15012.000000
# mean         5.782348
# std          1.860265
# min          2.333333
# 25%          4.000000
# 50%          5.778694
# 75%          7.000000
# max          9.500000
# Name: avgSchoolRating, dtype: float64

# %%
df['avgSchoolRating'].unique()
# Out:
# array([2.66666667, 3.        , 4.        , 3.66666667, 3.33333333,
#        7.66666667, 8.33333333, 7.        , 8.        , 9.        ,
#        6.        , 8.66666667, 5.33333333, 5.66666667, 9.33333333,
#        4.66666667, 6.66666667, 5.77869409, 6.5       , 5.        ,
#        4.33333333, 7.33333333, 9.5       , 8.5       , 3.5       ,
#        6.33333333, 2.33333333])

# %%
# lets plot living area by price again
fig, ax = plt.subplots(1, figsize=(12, 9))
plt.scatter(df['avgSchoolRating'], df['latestPrice'])
plt.xlabel('School Rating')
plt.ylabel("Home Price in USD (log scale)")
plt.yscale('log')
plt.title('Home Prices by Average School Rating', fontsize=30)
#plt.plot.scatter(x = df['livingAreaSqFt'], y = df['latestPrice'])
#ax.set_xlabel('Living Area in Sq Ft')
#ax.set_ylabel("House Price on log scale")
#ax.set_yscale('log')

#plt.show()
# Out:
# Text(0.5, 1.0, 'Home Prices by Average School Rating')

# %%
df['avgSchoolRating'] = df['avgSchoolRating'].round(decimals=1)
df.avgSchoolRating.value_counts().sort_index()
# Out:
# 2.3      64
# 2.7     205
# 3.0     614
# 3.3    1209
# 3.5       2
# 3.7     959
# 4.0    1120
# 4.3     729
# 4.7     503
# 5.0     817
# 5.3     717
# 5.7     543
# 5.8      50
# 6.0     886
# 6.3      63
# 6.5       2
# 6.7    1224
# 7.0    1899
# 7.3     446
# 7.7     232
# 8.0     719
# 8.3     705
# 8.5       6
# 8.7     528
# 9.0     670
# 9.3      74
# 9.5      26
# Name: avgSchoolRating, dtype: int64

# %%
df.boxplot(column=['latestPrice'], by=['avgSchoolRating'], figsize=(20,8), rot=0)

plt.ticklabel_format(style='plain', axis='y')

#plt.xticklabels(rotation=90)
plt.yscale('log')
plt.ylabel('Price in USD on log scale', fontsize=28)
plt.title('Home Prices Grouped by Avg School Rating', fontsize=36)

plt.suptitle('')
plt.show()

# %%
plt.rcParams["figure.figsize"] = (15,12)
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # FINAL STUFF

# %%
# Creating a new dataframe with the only the two columns we need for the image analysis:


image_price_df = df[['homeImage','latestPrice']]
image_price_df.head()
# Out:
#                                            homeImage  latestPrice
# 0  111373431_ffce26843283d3365c11d81b8e6bdc6f-p_f...       305000
# 1  120900430_8255c127be8dcf0a1a18b7563d987088-p_f...       295000
# 2  2084491383_a2ad649e1a7a098111dcea084a11c855-p_...       256125
# 3  120901374_b469367a619da85b1f5ceb69b675d88e-p_f...       240000
# 4  60134862_b1a48a3df3f111e005bb913873e98ce2-p_f.jpg       239900

# %%
image_price_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15012 entries, 0 to 15170
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   homeImage    15012 non-null  object
#  1   latestPrice  15012 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 351.8+ KB

# %%
# Renaming the columns 
image_price_df.rename(columns= 
              {'homeImage':'Image Name','latestPrice':'Price'}, inplace=True)
# Out:
# /Users/sangeetajayakar/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
image_price_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15012 entries, 0 to 15170
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Image Name  15012 non-null  object
#  1   Price       15012 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 351.8+ KB

# %%
image_price_df.head()
# Out:
#                                           Image Name   Price
# 0  111373431_ffce26843283d3365c11d81b8e6bdc6f-p_f...  305000
# 1  120900430_8255c127be8dcf0a1a18b7563d987088-p_f...  295000
# 2  2084491383_a2ad649e1a7a098111dcea084a11c855-p_...  256125
# 3  120901374_b469367a619da85b1f5ceb69b675d88e-p_f...  240000
# 4  60134862_b1a48a3df3f111e005bb913873e98ce2-p_f.jpg  239900

# %% [markdown]
# #### The final cleaned dataframe can be exported to a new csv file.
# commented out to not create multiple files

# %%
# output this new csv file 
#path_to_folder = '/Users/sangeetajayakar/Springboard_Course/AustinHousingFiles'
#new_file_name = 'cleaned_AH_data.csv'


#image_price_df.to_csv(r'/Users/sangeetajayakar/Springboard_Course/AustinHousingFiles/cleaned_AH_data_v2.csv', index=False)

# %% [markdown]
# ### Dataset with home features

# %% [markdown]
# Making a dataframe with the features of the home to add to the neural network models along with the images.

# %%
# check that the df is as we expect it
print(df.shape)
df.head()
# Out:
# (15012, 47)
#          zpid          city          streetAddress zipcode  \
# 0   111373431  pflugerville   14424 Lake Victor Dr   78660
# 1   120900430  pflugerville     1104 Strickling Dr   78660
# 2  2084491383  pflugerville    1408 Fort Dessau Rd   78660
# 3   120901374  pflugerville     1025 Strickling Dr   78660
# 4    60134862  pflugerville  15005 Donna Jane Loop   78660
#
#                                          description   latitude  longitude  \
# 0  14424 Lake Victor Dr, Pflugerville, TX 78660 i...  30.430632 -97.663078
# 1  Absolutely GORGEOUS 4 Bedroom home with 2 full...  30.432673 -97.661697
# 2  Under construction - estimated completion in A...  30.409748 -97.639771
# 3  Absolutely darling one story home in charming ...  30.432112 -97.661659
# 4  Brimming with appeal & warm livability! Sleek ...  30.437368 -97.656860
#
#    propertyTaxRate  garageSpaces  hasAssociation  ...  numOfMiddleSchools  \
# 0             1.98             2            True  ...                   1
# 1             1.98             2            True  ...                   1
# 2             1.98             0            True  ...                   1
# 3             1.98             2            True  ...                   1
# 4             1.98             0            True  ...                   1
#
#    numOfHighSchools  avgSchoolDistance  avgSchoolRating  avgSchoolSize  \
# 0                 1           1.266667              2.7           1063
# 1                 1           1.400000              2.7           1063
# 2                 1           1.200000              3.0           1108
# 3                 1           1.400000              2.7           1063
# 4                 1           1.133333              4.0           1223
#
#   MedianStudentsPerTeacher  numOfBathrooms  numOfBedrooms  numOfStories  \
# 0                       14             3.0              4             2
# 1                       14             2.0              4             1
# 2                       14             2.0              3             1
# 3                       14             2.0              3             1
# 4                       14             3.0              3             2
#
#                                            homeImage
# 0  111373431_ffce26843283d3365c11d81b8e6bdc6f-p_f...
# 1  120900430_8255c127be8dcf0a1a18b7563d987088-p_f...
# 2  2084491383_a2ad649e1a7a098111dcea084a11c855-p_...
# 3  120901374_b469367a619da85b1f5ceb69b675d88e-p_f...
# 4  60134862_b1a48a3df3f111e005bb913873e98ce2-p_f.jpg
#
# [5 rows x 47 columns]

# %%
features = [ 'latestPrice','homeImage','zipcode','longitude', 
            'livingAreaSqFt','numOfBathrooms', 'numOfBedrooms',
            'numOfPrimarySchools', 'numOfHighSchools', 'avgSchoolRating']

# %%
features_df = df[features]
features_df.head()
# Out:
#    latestPrice                                          homeImage zipcode  \
# 0       305000  111373431_ffce26843283d3365c11d81b8e6bdc6f-p_f...   78660
# 1       295000  120900430_8255c127be8dcf0a1a18b7563d987088-p_f...   78660
# 2       256125  2084491383_a2ad649e1a7a098111dcea084a11c855-p_...   78660
# 3       240000  120901374_b469367a619da85b1f5ceb69b675d88e-p_f...   78660
# 4       239900  60134862_b1a48a3df3f111e005bb913873e98ce2-p_f.jpg   78660
#
#    longitude  livingAreaSqFt  numOfBathrooms  numOfBedrooms  \
# 0 -97.663078          2601.0             3.0              4
# 1 -97.661697          1768.0             2.0              4
# 2 -97.639771          1478.0             2.0              3
# 3 -97.661659          1678.0             2.0              3
# 4 -97.656860          2132.0             3.0              3
#
#    numOfPrimarySchools  numOfHighSchools  avgSchoolRating
# 0                    1                 1              2.7
# 1                    1                 1              2.7
# 2                    0                 1              3.0
# 3                    1                 1              2.7
# 4                    1                 1              4.0

# %%
features_df.describe().astype(int)
# Out:
#        latestPrice  longitude  livingAreaSqFt  numOfBathrooms  numOfBedrooms  \
# count        15012      15012           15012           15012          15012
# mean        512613        -97            2196               2              3
# std         442040          0            1023               1              0
# min          70000        -98             300               1              1
# 25%         309033        -97            1486               2              3
# 50%         405000        -97            1976               3              3
# 75%         575000        -97            2686               3              4
# max       13500000        -97           15394              13             10
#
#        numOfPrimarySchools  numOfHighSchools  avgSchoolRating
# count                15012             15012            15012
# mean                     0                 0                5
# std                      0                 0                1
# min                      0                 0                2
# 25%                      1                 1                4
# 50%                      1                 1                5
# 75%                      1                 1                7
# max                      2                 2                9

# %%
features_df.latestPrice.describe().astype(int)
# Out:
# count       15012
# mean       512613
# std        442040
# min         70000
# 25%        309033
# 50%        405000
# 75%        575000
# max      13500000
# Name: latestPrice, dtype: int64

# %%
print('The number of homes under $1M: ', + len(features_df[features_df['latestPrice']<1000000]))
print('The percentage of homes under $1M: ' + 
      str(int(len(features_df[features_df['latestPrice']<1000000])/len(features_df)*100))+ '%')
# Out:
# The number of homes under $1M:  14068
# The percentage of homes under $1M: 93%

# %%
features_df.rename(columns= 
              {'latestPrice':'Price', 'homeImage': 'Image Name'}, inplace=True)
# Out:
# /Users/sangeetajayakar/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
features_df['Image Name'] = features_df['Image Name'].str.rstrip('.jpg')
# Out:
# <ipython-input-137-0fbc0d12da16>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features_df['Image Name'] = features_df['Image Name'].str.rstrip('.jpg')

# %%
features_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15012 entries, 0 to 15170
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Price                15012 non-null  int64
#  1   Image Name           15012 non-null  object
#  2   zipcode              15012 non-null  object
#  3   longitude            15012 non-null  float64
#  4   livingAreaSqFt       15012 non-null  float64
#  5   numOfBathrooms       15012 non-null  float64
#  6   numOfBedrooms        15012 non-null  int64
#  7   numOfPrimarySchools  15012 non-null  int64
#  8   numOfHighSchools     15012 non-null  int64
#  9   avgSchoolRating      15012 non-null  float64
# dtypes: float64(4), int64(4), object(2)
# memory usage: 1.3+ MB

# %%
features_df.head()
# Out:
#     Price                                       Image Name zipcode  longitude  \
# 0  305000   111373431_ffce26843283d3365c11d81b8e6bdc6f-p_f   78660 -97.663078
# 1  295000   120900430_8255c127be8dcf0a1a18b7563d987088-p_f   78660 -97.661697
# 2  256125  2084491383_a2ad649e1a7a098111dcea084a11c855-p_f   78660 -97.639771
# 3  240000   120901374_b469367a619da85b1f5ceb69b675d88e-p_f   78660 -97.661659
# 4  239900    60134862_b1a48a3df3f111e005bb913873e98ce2-p_f   78660 -97.656860
#
#    livingAreaSqFt  numOfBathrooms  numOfBedrooms  numOfPrimarySchools  \
# 0          2601.0             3.0              4                    1
# 1          1768.0             2.0              4                    1
# 2          1478.0             2.0              3                    0
# 3          1678.0             2.0              3                    1
# 4          2132.0             3.0              3                    1
#
#    numOfHighSchools  avgSchoolRating
# 0                 1              2.7
# 1                 1              2.7
# 2                 1              3.0
# 3                 1              2.7
# 4                 1              4.0

# %%
# output to a new csv file

#commented out to prevent duplicate files
#features_df.to_csv(r'/Users/sangeetajayakar/Springboard_Course/AustinHousingFiles/cleaned_features_data_v1.csv', index=False)
