# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import os

# %%
vaersdata = '/Users/sangeetajayakar/Springboard_Course/Files_for_second_capstone/2021VAERSDATA.csv'
vaerssymptoms = '/Users/sangeetajayakar/Springboard_Course/Files_for_second_capstone/2021VAERSSYMPTOMS.csv'
vaersvax = '/Users/sangeetajayakar/Springboard_Course/Files_for_second_capstone/2021VAERSVAX.csv'

# %%
import chardet
with open(vaersdata, 'rb') as rawdata:
    result = chardet.detect(rawdata.read(100000))
result
# Out:
# {'encoding': 'ISO-8859-1', 'confidence': 0.73, 'language': ''}

# %%
vaers_data = pd.read_csv(vaersdata, encoding='ISO-8859-1')
vaers_data.head()
# Out:
#    VAERS_ID    RECVDATE STATE  AGE_YRS  CAGE_YR  CAGE_MO SEX RPT_DATE  \
# 0    916710  01/01/2021    MO     23.0     23.0      NaN   F      NaN
# 1    916720  01/01/2021    NY     23.0     23.0      NaN   M      NaN
# 2    916741  01/01/2021    AR     68.0     68.0      NaN   F      NaN
# 3    916772  01/01/2021    GA     55.0     55.0      NaN   M      NaN
# 4    916790  01/01/2021    TN     52.0     52.0      NaN   F      NaN
#
#                                         SYMPTOM_TEXT DIED  ...  \
# 0  Acute appendicitis, onset morning of 1/1/2021 ...  NaN  ...
# 1  Patient made statements that he was having a h...  NaN  ...
# 2  on dec 22 I felt some myalgias, chills, fatigu...  NaN  ...
# 3  Vaccine on 12/22/2020 and started feeling bad ...  NaN  ...
# 4  Flushing, sweating, increased heart rate proce...  NaN  ...
#
#                                              CUR_ILL  \
# 0                                                NaN
# 1                                                NaN
# ...

# %%
vaers_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5351 entries, 0 to 5350
# Data columns (total 35 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   VAERS_ID      5351 non-null   int64
#  1   RECVDATE      5351 non-null   object
#  2   STATE         4449 non-null   object
#  3   AGE_YRS       4350 non-null   float64
#  4   CAGE_YR       3153 non-null   float64
#  5   CAGE_MO       11 non-null     float64
#  6   SEX           5351 non-null   object
#  7   RPT_DATE      16 non-null     object
#  8   SYMPTOM_TEXT  5351 non-null   object
#  9   DIED          810 non-null    object
#  10  DATEDIED      747 non-null    object
#  11  L_THREAT      549 non-null    object
#  12  ER_VISIT      3 non-null      object
#  13  HOSPITAL      1747 non-null   object
#  14  HOSPDAYS      1133 non-null   float64
#  15  X_STAY        15 non-null     object
#  16  DISABLE       329 non-null    object
#  17  RECOVD        5046 non-null   object
# ...

# %%
vaers_data.describe()
# Out:
#            VAERS_ID      AGE_YRS      CAGE_YR    CAGE_MO     HOSPDAYS  \
# count  5.351000e+03  4350.000000  3153.000000  11.000000  1133.000000
# mean   9.683927e+05    57.091607    59.641611   0.136364     3.336275
# std    3.119518e+04    20.498795    20.983655   0.237793     3.417488
# min    9.167100e+05     0.330000     0.000000   0.000000     1.000000
# 25%    9.386440e+05    40.000000    42.000000   0.000000     1.000000
# 50%    9.720920e+05    56.000000    60.000000   0.000000     2.000000
# 75%    9.945030e+05    74.000000    77.000000   0.200000     4.000000
# max    1.024853e+06   105.000000   105.000000   0.600000    36.000000
#
#             NUMDAYS    FORM_VERS
# count   4522.000000  5351.000000
# mean      24.695710     1.997010
# std      689.221079     0.054605
# min        0.000000     1.000000
# 25%        0.000000     2.000000
# 50%        1.000000     2.000000
# 75%        5.000000     2.000000
# max    36896.000000     2.000000

# %%
vaers_symptoms = pd.read_csv(vaerssymptoms, encoding='ISO-8859-1')
vaers_symptoms.head()
# Out:
#    VAERS_ID          SYMPTOM1  SYMPTOMVERSION1  \
# 0    916710      Appendicitis             23.1
# 1    916720         Dysphagia             23.1
# 2    916741            Chills             23.1
# 3    916741           Myalgia             23.1
# 4    916772  Feeling abnormal             23.1
#
#                                SYMPTOM2  SYMPTOMVERSION2             SYMPTOM3  \
# 0  Band neutrophil percentage increased             23.1              Surgery
# 1                              Dyspnoea             23.1                  NaN
# 2        Complex regional pain syndrome             23.1              Fatigue
# 3                     Pain in extremity             23.1  Peripheral swelling
# 4              SARS-CoV-2 test positive             23.1                  NaN
#
#    SYMPTOMVERSION3                          SYMPTOM4  SYMPTOMVERSION4  \
# 0             23.1  White blood cell count increased             23.1
# ...

# %%
vaers_symptoms.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8640 entries, 0 to 8639
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   VAERS_ID         8640 non-null   int64
#  1   SYMPTOM1         8640 non-null   object
#  2   SYMPTOMVERSION1  8640 non-null   float64
#  3   SYMPTOM2         7059 non-null   object
#  4   SYMPTOMVERSION2  7059 non-null   float64
#  5   SYMPTOM3         5775 non-null   object
#  6   SYMPTOMVERSION3  5775 non-null   float64
#  7   SYMPTOM4         4808 non-null   object
#  8   SYMPTOMVERSION4  4808 non-null   float64
#  9   SYMPTOM5         3992 non-null   object
#  10  SYMPTOMVERSION5  3992 non-null   float64
# dtypes: float64(5), int64(1), object(5)
# memory usage: 742.6+ KB

# %%
vaers_vax = pd.read_csv(vaersvax, encoding='ISO-8859-1')
vaers_vax.head()
# Out:
#    VAERS_ID VAX_TYPE         VAX_MANU  VAX_LOT VAX_DOSE_SERIES VAX_ROUTE  \
# 0    916710  COVID19          MODERNA      NaN               1        IM
# 1    916720  COVID19          MODERNA  011L20A               1        IM
# 2    916741  COVID19  PFIZER\BIONTECH   EH9899               1       SYR
# 3    916772  COVID19  PFIZER\BIONTECH   EJ1685             UNK        IM
# 4    916790  COVID19  PFIZER\BIONTECH      NaN               1        IM
#
#   VAX_SITE                             VAX_NAME
# 0       LA          COVID19 (COVID19 (MODERNA))
# 1       AR          COVID19 (COVID19 (MODERNA))
# 2       LA  COVID19 (COVID19 (PFIZER-BIONTECH))
# 3       LA  COVID19 (COVID19 (PFIZER-BIONTECH))
# 4       RA  COVID19 (COVID19 (PFIZER-BIONTECH))

# %%
vaers_vax.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5471 entries, 0 to 5470
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   VAERS_ID         5471 non-null   int64
#  1   VAX_TYPE         5471 non-null   object
#  2   VAX_MANU         5471 non-null   object
#  3   VAX_LOT          3370 non-null   object
#  4   VAX_DOSE_SERIES  5462 non-null   object
#  5   VAX_ROUTE        3337 non-null   object
#  6   VAX_SITE         3608 non-null   object
#  7   VAX_NAME         5471 non-null   object
# dtypes: int64(1), object(7)
# memory usage: 342.1+ KB

# %%
#what vaccines are there?
vaers_vax['VAX_TYPE'].unique()
# Out:
# array(['COVID19', 'FLU4', 'DTAPHEPBIP', 'HIBV', 'RV1', 'UNK', 'FLUX',
#        'MMR', 'VARZOS', 'DTAP', 'PPV', 'HPV9', 'CHOL', 'DT', 'TTOX',
#        'FLU3', 'FLUC3', 'FLUC4', 'FLUR4', 'MNQ', 'HPV4', 'TDAP', 'FLUA3',
#        'HEPA', 'VARCEL', 'FLUA4', 'HEP', 'PNC13'], dtype=object)

# %%
print(vaers_data.shape)
print(vaers_symptoms.shape)
print(vaers_vax.shape)
# Out:
# (5351, 35)
# (8640, 11)
# (5471, 8)
